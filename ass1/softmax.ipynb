# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.377453
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *As a result of dot product of (X_dev and W), we get 10 scores per case. Probability of choosing a correct class among ten classes is 0.1. So we can assume that we will get loss of -np.log(0.1)*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.612249 analytic: 0.612249, relative error: 1.607493e-07
# numerical: 3.522602 analytic: 3.522602, relative error: 9.771258e-09
# numerical: 1.812636 analytic: 1.812636, relative error: 2.379578e-08
# numerical: -0.472207 analytic: -0.472207, relative error: 3.170689e-08
# numerical: 0.701468 analytic: 0.701468, relative error: 6.482945e-08
# numerical: 0.590334 analytic: 0.590333, relative error: 9.328778e-08
# numerical: -1.005975 analytic: -1.005975, relative error: 5.285456e-08
# numerical: -0.318440 analytic: -0.318440, relative error: 1.952350e-07
# numerical: 4.544124 analytic: 4.544123, relative error: 1.062959e-08
# numerical: -0.215756 analytic: -0.215756, relative error: 1.218066e-07
# numerical: -4.397515 analytic: -4.397514, relative error: 1.287511e-08
# numerical: -2.371490 analytic: -2.371490, relative error: 2.186515e-08
# numerical: -1.602150 analytic: -1.602150, relative error: 3.319575e-08
# numerical: 1.138771 analytic: 1.138771, relative error: 2.466735e-08
# numerical: -0.952054 analytic: -0.952054, relative error: 5.269686e-09
# numerical: 0.158906 analytic: 0.158906, relative error: 1.954979e-07
# numerical: 1.298773 analytic: 1.298773, relative error: 4.545052e-08
# numerical: -0.010132 analytic: -0.010132, relative error: 1.840798e-06
# numerical: -0.416028 analytic: -0.416028, relative error: 4.690750e-08
# numerical: 1.521710 analytic: 1.521709, relative error: 4.866606e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.377453e+00 computed in 0.111275s
# vectorized loss: 2.377453e+00 computed in 0.005014s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-10, 5e-10, 9e-10, 1e-9, 5e-9, 9e-9, 
                  1e-8, 5e-8, 9e-8, 1e-7, 5e-7, 9e-7, 
                  1e-6, 5e-6, 9e-6, 1e-5, 5e-5, 9e-5, 
                 ]
regularization_strengths = [
                            2.5e0, 7.5e0, 2.5e1, 7.5e1,
                            2.5e2, 7.5e2, 2.5e3, 7.5e3,
                            2.5e4, 7.5e4, 2.5e5, 7.5e5,
                            2.5e6, 7.5e6, 2.5e7, 7.5e7,
                           ]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for (lr, reg)  in [(x,y) for x in learning_rates for y in regularization_strengths]:
    #print('####')
    #print(lr, reg)
    softmax = Softmax()
    softmax.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=False)
    train_accuracy = np.mean(softmax.predict((X_train)) == y_train)
    val_accuracy = np.mean(softmax.predict(X_val) == y_val)
    results[(lr, reg)] = (train_accuracy, val_accuracy)
    if(val_accuracy > best_val):
        best_val = val_accuracy
        best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.000000e-10 reg 2.500000e+00 train accuracy: 0.101020 val accuracy: 0.104000
# lr 1.000000e-10 reg 7.500000e+00 train accuracy: 0.103510 val accuracy: 0.112000
# lr 1.000000e-10 reg 2.500000e+01 train accuracy: 0.113796 val accuracy: 0.127000
# lr 1.000000e-10 reg 7.500000e+01 train accuracy: 0.114469 val accuracy: 0.103000
# lr 1.000000e-10 reg 2.500000e+02 train accuracy: 0.106429 val accuracy: 0.108000
# lr 1.000000e-10 reg 7.500000e+02 train accuracy: 0.093122 val accuracy: 0.104000
# lr 1.000000e-10 reg 2.500000e+03 train accuracy: 0.086429 val accuracy: 0.069000
# lr 1.000000e-10 reg 7.500000e+03 train accuracy: 0.128020 val accuracy: 0.122000
# lr 1.000000e-10 reg 2.500000e+04 train accuracy: 0.123592 val accuracy: 0.135000
# lr 1.000000e-10 reg 7.500000e+04 train accuracy: 0.071041 val accuracy: 0.082000
# lr 1.000000e-10 reg 2.500000e+05 train accuracy: 0.116469 val accuracy: 0.126000
# lr 1.000000e-10 reg 7.500000e+05 train accuracy: 0.112633 val accuracy: 0.132000
# lr 1.000000e-10 reg 2.500000e+06 train accuracy: 0.082673 val accuracy: 0.093000
# lr 1.000000e-10 reg 7.500000e+06 train accuracy: 0.092204 val accuracy: 0.095000
# lr 1.000000e-10 reg 2.500000e+07 train accuracy: 0.183204 val accuracy: 0.194000
# lr 1.000000e-10 reg 7.500000e+07 train accuracy: 0.244224 val accuracy: 0.261000
# lr 5.000000e-10 reg 2.500000e+00 train accuracy: 0.085000 val accuracy: 0.089000
# lr 5.000000e-10 reg 7.500000e+00 train accuracy: 0.158490 val accuracy: 0.169000
# lr 5.000000e-10 reg 2.500000e+01 train accuracy: 0.087939 val accuracy: 0.096000
# lr 5.000000e-10 reg 7.500000e+01 train accuracy: 0.106224 val accuracy: 0.110000
# lr 5.000000e-10 reg 2.500000e+02 train accuracy: 0.083429 val accuracy: 0.106000
# lr 5.000000e-10 reg 7.500000e+02 train accuracy: 0.096367 val accuracy: 0.107000
# lr 5.000000e-10 reg 2.500000e+03 train accuracy: 0.106939 val accuracy: 0.116000
# lr 5.000000e-10 reg 7.500000e+03 train accuracy: 0.099306 val accuracy: 0.113000
# lr 5.000000e-10 reg 2.500000e+04 train accuracy: 0.093082 val accuracy: 0.098000
# lr 5.000000e-10 reg 7.500000e+04 train accuracy: 0.101653 val accuracy: 0.111000
# lr 5.000000e-10 reg 2.500000e+05 train accuracy: 0.086837 val accuracy: 0.091000
# lr 5.000000e-10 reg 7.500000e+05 train accuracy: 0.087980 val accuracy: 0.095000
# lr 5.000000e-10 reg 2.500000e+06 train accuracy: 0.156857 val accuracy: 0.150000
# lr 5.000000e-10 reg 7.500000e+06 train accuracy: 0.247878 val accuracy: 0.261000
# lr 5.000000e-10 reg 2.500000e+07 train accuracy: 0.245980 val accuracy: 0.259000
# lr 5.000000e-10 reg 7.500000e+07 train accuracy: 0.243429 val accuracy: 0.257000
# lr 9.000000e-10 reg 2.500000e+00 train accuracy: 0.120694 val accuracy: 0.108000
# lr 9.000000e-10 reg 7.500000e+00 train accuracy: 0.111714 val accuracy: 0.114000
# lr 9.000000e-10 reg 2.500000e+01 train accuracy: 0.076306 val accuracy: 0.089000
# lr 9.000000e-10 reg 7.500000e+01 train accuracy: 0.107531 val accuracy: 0.095000
# lr 9.000000e-10 reg 2.500000e+02 train accuracy: 0.102102 val accuracy: 0.085000
# lr 9.000000e-10 reg 7.500000e+02 train accuracy: 0.114755 val accuracy: 0.120000
# lr 9.000000e-10 reg 2.500000e+03 train accuracy: 0.105612 val accuracy: 0.097000
# lr 9.000000e-10 reg 7.500000e+03 train accuracy: 0.098082 val accuracy: 0.107000
# lr 9.000000e-10 reg 2.500000e+04 train accuracy: 0.089224 val accuracy: 0.082000
# lr 9.000000e-10 reg 7.500000e+04 train accuracy: 0.097224 val accuracy: 0.115000
# lr 9.000000e-10 reg 2.500000e+05 train accuracy: 0.126939 val accuracy: 0.125000
# lr 9.000000e-10 reg 7.500000e+05 train accuracy: 0.124939 val accuracy: 0.134000
# lr 9.000000e-10 reg 2.500000e+06 train accuracy: 0.246122 val accuracy: 0.254000
# lr 9.000000e-10 reg 7.500000e+06 train accuracy: 0.244776 val accuracy: 0.263000
# lr 9.000000e-10 reg 2.500000e+07 train accuracy: 0.241735 val accuracy: 0.256000
# lr 9.000000e-10 reg 7.500000e+07 train accuracy: 0.243347 val accuracy: 0.263000
# lr 1.000000e-09 reg 2.500000e+00 train accuracy: 0.118082 val accuracy: 0.121000
# lr 1.000000e-09 reg 7.500000e+00 train accuracy: 0.090673 val accuracy: 0.096000
# lr 1.000000e-09 reg 2.500000e+01 train accuracy: 0.112163 val accuracy: 0.127000
# lr 1.000000e-09 reg 7.500000e+01 train accuracy: 0.111816 val accuracy: 0.107000
# lr 1.000000e-09 reg 2.500000e+02 train accuracy: 0.093878 val accuracy: 0.106000
# lr 1.000000e-09 reg 7.500000e+02 train accuracy: 0.112796 val accuracy: 0.116000
# lr 1.000000e-09 reg 2.500000e+03 train accuracy: 0.093041 val accuracy: 0.110000
# lr 1.000000e-09 reg 7.500000e+03 train accuracy: 0.099694 val accuracy: 0.092000
# lr 1.000000e-09 reg 2.500000e+04 train accuracy: 0.108245 val accuracy: 0.089000
# lr 1.000000e-09 reg 7.500000e+04 train accuracy: 0.102633 val accuracy: 0.112000
# lr 1.000000e-09 reg 2.500000e+05 train accuracy: 0.115245 val accuracy: 0.115000
# lr 1.000000e-09 reg 7.500000e+05 train accuracy: 0.098429 val accuracy: 0.095000
# lr 1.000000e-09 reg 2.500000e+06 train accuracy: 0.250143 val accuracy: 0.267000
# lr 1.000000e-09 reg 7.500000e+06 train accuracy: 0.245755 val accuracy: 0.254000
# lr 1.000000e-09 reg 2.500000e+07 train accuracy: 0.239571 val accuracy: 0.254000
# lr 1.000000e-09 reg 7.500000e+07 train accuracy: 0.257143 val accuracy: 0.265000
# lr 5.000000e-09 reg 2.500000e+00 train accuracy: 0.121510 val accuracy: 0.143000
# lr 5.000000e-09 reg 7.500000e+00 train accuracy: 0.119469 val accuracy: 0.130000
# lr 5.000000e-09 reg 2.500000e+01 train accuracy: 0.139959 val accuracy: 0.141000
# lr 5.000000e-09 reg 7.500000e+01 train accuracy: 0.151612 val accuracy: 0.142000
# lr 5.000000e-09 reg 2.500000e+02 train accuracy: 0.117551 val accuracy: 0.113000
# lr 5.000000e-09 reg 7.500000e+02 train accuracy: 0.135449 val accuracy: 0.151000
# lr 5.000000e-09 reg 2.500000e+03 train accuracy: 0.126816 val accuracy: 0.127000
# lr 5.000000e-09 reg 7.500000e+03 train accuracy: 0.129612 val accuracy: 0.152000
# lr 5.000000e-09 reg 2.500000e+04 train accuracy: 0.138633 val accuracy: 0.143000
# lr 5.000000e-09 reg 7.500000e+04 train accuracy: 0.138837 val accuracy: 0.137000
# lr 5.000000e-09 reg 2.500000e+05 train accuracy: 0.245959 val accuracy: 0.265000
# lr 5.000000e-09 reg 7.500000e+05 train accuracy: 0.252510 val accuracy: 0.263000
# lr 5.000000e-09 reg 2.500000e+06 train accuracy: 0.251816 val accuracy: 0.259000
# lr 5.000000e-09 reg 7.500000e+06 train accuracy: 0.243776 val accuracy: 0.259000
# lr 5.000000e-09 reg 2.500000e+07 train accuracy: 0.238653 val accuracy: 0.254000
# lr 5.000000e-09 reg 7.500000e+07 train accuracy: 0.222408 val accuracy: 0.208000
# lr 9.000000e-09 reg 2.500000e+00 train accuracy: 0.142776 val accuracy: 0.141000
# lr 9.000000e-09 reg 7.500000e+00 train accuracy: 0.147286 val accuracy: 0.147000
# lr 9.000000e-09 reg 2.500000e+01 train accuracy: 0.152347 val accuracy: 0.140000
# lr 9.000000e-09 reg 7.500000e+01 train accuracy: 0.144429 val accuracy: 0.137000
# lr 9.000000e-09 reg 2.500000e+02 train accuracy: 0.155265 val accuracy: 0.167000
# lr 9.000000e-09 reg 7.500000e+02 train accuracy: 0.147204 val accuracy: 0.152000
# lr 9.000000e-09 reg 2.500000e+03 train accuracy: 0.146122 val accuracy: 0.135000
# lr 9.000000e-09 reg 7.500000e+03 train accuracy: 0.155490 val accuracy: 0.168000
# lr 9.000000e-09 reg 2.500000e+04 train accuracy: 0.172408 val accuracy: 0.161000
# lr 9.000000e-09 reg 7.500000e+04 train accuracy: 0.234531 val accuracy: 0.238000
# lr 9.000000e-09 reg 2.500000e+05 train accuracy: 0.268020 val accuracy: 0.278000
# lr 9.000000e-09 reg 7.500000e+05 train accuracy: 0.256714 val accuracy: 0.270000
# lr 9.000000e-09 reg 2.500000e+06 train accuracy: 0.248102 val accuracy: 0.258000
# lr 9.000000e-09 reg 7.500000e+06 train accuracy: 0.234122 val accuracy: 0.253000
# lr 9.000000e-09 reg 2.500000e+07 train accuracy: 0.268796 val accuracy: 0.260000
# lr 9.000000e-09 reg 7.500000e+07 train accuracy: 0.214265 val accuracy: 0.207000
# lr 1.000000e-08 reg 2.500000e+00 train accuracy: 0.153122 val accuracy: 0.191000
# lr 1.000000e-08 reg 7.500000e+00 train accuracy: 0.145857 val accuracy: 0.145000
# lr 1.000000e-08 reg 2.500000e+01 train accuracy: 0.167673 val accuracy: 0.155000
# lr 1.000000e-08 reg 7.500000e+01 train accuracy: 0.153714 val accuracy: 0.167000
# lr 1.000000e-08 reg 2.500000e+02 train accuracy: 0.158184 val accuracy: 0.150000
# lr 1.000000e-08 reg 7.500000e+02 train accuracy: 0.155041 val accuracy: 0.150000
# lr 1.000000e-08 reg 2.500000e+03 train accuracy: 0.153347 val accuracy: 0.134000
# lr 1.000000e-08 reg 7.500000e+03 train accuracy: 0.143184 val accuracy: 0.138000
# lr 1.000000e-08 reg 2.500000e+04 train accuracy: 0.185776 val accuracy: 0.209000
# lr 1.000000e-08 reg 7.500000e+04 train accuracy: 0.239449 val accuracy: 0.231000
# lr 1.000000e-08 reg 2.500000e+05 train accuracy: 0.267592 val accuracy: 0.279000
# lr 1.000000e-08 reg 7.500000e+05 train accuracy: 0.253531 val accuracy: 0.272000
# lr 1.000000e-08 reg 2.500000e+06 train accuracy: 0.242571 val accuracy: 0.255000
# lr 1.000000e-08 reg 7.500000e+06 train accuracy: 0.240327 val accuracy: 0.257000
# lr 1.000000e-08 reg 2.500000e+07 train accuracy: 0.235531 val accuracy: 0.234000
# lr 1.000000e-08 reg 7.500000e+07 train accuracy: 0.204265 val accuracy: 0.187000
# lr 5.000000e-08 reg 2.500000e+00 train accuracy: 0.225163 val accuracy: 0.228000
# lr 5.000000e-08 reg 7.500000e+00 train accuracy: 0.211224 val accuracy: 0.210000
# lr 5.000000e-08 reg 2.500000e+01 train accuracy: 0.214265 val accuracy: 0.200000
# lr 5.000000e-08 reg 7.500000e+01 train accuracy: 0.217429 val accuracy: 0.204000
# lr 5.000000e-08 reg 2.500000e+02 train accuracy: 0.223469 val accuracy: 0.239000
# lr 5.000000e-08 reg 7.500000e+02 train accuracy: 0.224204 val accuracy: 0.219000
# lr 5.000000e-08 reg 2.500000e+03 train accuracy: 0.233306 val accuracy: 0.242000
# lr 5.000000e-08 reg 7.500000e+03 train accuracy: 0.273429 val accuracy: 0.290000
# lr 5.000000e-08 reg 2.500000e+04 train accuracy: 0.325673 val accuracy: 0.337000
# lr 5.000000e-08 reg 7.500000e+04 train accuracy: 0.302959 val accuracy: 0.311000
# lr 5.000000e-08 reg 2.500000e+05 train accuracy: 0.267959 val accuracy: 0.278000
# lr 5.000000e-08 reg 7.500000e+05 train accuracy: 0.239429 val accuracy: 0.248000
# lr 5.000000e-08 reg 2.500000e+06 train accuracy: 0.243143 val accuracy: 0.255000
# lr 5.000000e-08 reg 7.500000e+06 train accuracy: 0.220204 val accuracy: 0.220000
# lr 5.000000e-08 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-08 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-08 reg 2.500000e+00 train accuracy: 0.238694 val accuracy: 0.239000
# lr 9.000000e-08 reg 7.500000e+00 train accuracy: 0.246367 val accuracy: 0.233000
# lr 9.000000e-08 reg 2.500000e+01 train accuracy: 0.242306 val accuracy: 0.262000
# lr 9.000000e-08 reg 7.500000e+01 train accuracy: 0.247163 val accuracy: 0.242000
# lr 9.000000e-08 reg 2.500000e+02 train accuracy: 0.250918 val accuracy: 0.262000
# lr 9.000000e-08 reg 7.500000e+02 train accuracy: 0.259510 val accuracy: 0.265000
# lr 9.000000e-08 reg 2.500000e+03 train accuracy: 0.281020 val accuracy: 0.278000
# lr 9.000000e-08 reg 7.500000e+03 train accuracy: 0.344408 val accuracy: 0.345000
# lr 9.000000e-08 reg 2.500000e+04 train accuracy: 0.325592 val accuracy: 0.346000
# lr 9.000000e-08 reg 7.500000e+04 train accuracy: 0.293408 val accuracy: 0.305000
# lr 9.000000e-08 reg 2.500000e+05 train accuracy: 0.266122 val accuracy: 0.278000
# lr 9.000000e-08 reg 7.500000e+05 train accuracy: 0.255653 val accuracy: 0.259000
# lr 9.000000e-08 reg 2.500000e+06 train accuracy: 0.228755 val accuracy: 0.236000
# lr 9.000000e-08 reg 7.500000e+06 train accuracy: 0.187143 val accuracy: 0.186000
# lr 9.000000e-08 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-08 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-07 reg 2.500000e+00 train accuracy: 0.244571 val accuracy: 0.239000
# lr 1.000000e-07 reg 7.500000e+00 train accuracy: 0.249571 val accuracy: 0.257000
# lr 1.000000e-07 reg 2.500000e+01 train accuracy: 0.246245 val accuracy: 0.271000
# lr 1.000000e-07 reg 7.500000e+01 train accuracy: 0.251367 val accuracy: 0.257000
# lr 1.000000e-07 reg 2.500000e+02 train accuracy: 0.256796 val accuracy: 0.259000
# lr 1.000000e-07 reg 7.500000e+02 train accuracy: 0.258000 val accuracy: 0.269000
# lr 1.000000e-07 reg 2.500000e+03 train accuracy: 0.292449 val accuracy: 0.295000
# lr 1.000000e-07 reg 7.500000e+03 train accuracy: 0.352939 val accuracy: 0.357000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.327306 val accuracy: 0.339000
# lr 1.000000e-07 reg 7.500000e+04 train accuracy: 0.297531 val accuracy: 0.313000
# lr 1.000000e-07 reg 2.500000e+05 train accuracy: 0.255265 val accuracy: 0.270000
# lr 1.000000e-07 reg 7.500000e+05 train accuracy: 0.250102 val accuracy: 0.254000
# lr 1.000000e-07 reg 2.500000e+06 train accuracy: 0.230347 val accuracy: 0.236000
# lr 1.000000e-07 reg 7.500000e+06 train accuracy: 0.181653 val accuracy: 0.197000
# lr 1.000000e-07 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-07 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-07 reg 2.500000e+00 train accuracy: 0.319898 val accuracy: 0.304000
# lr 5.000000e-07 reg 7.500000e+00 train accuracy: 0.322327 val accuracy: 0.296000
# lr 5.000000e-07 reg 2.500000e+01 train accuracy: 0.322939 val accuracy: 0.328000
# lr 5.000000e-07 reg 7.500000e+01 train accuracy: 0.323490 val accuracy: 0.318000
# lr 5.000000e-07 reg 2.500000e+02 train accuracy: 0.338980 val accuracy: 0.347000
# lr 5.000000e-07 reg 7.500000e+02 train accuracy: 0.381204 val accuracy: 0.394000
# lr 5.000000e-07 reg 2.500000e+03 train accuracy: 0.383327 val accuracy: 0.394000
# lr 5.000000e-07 reg 7.500000e+03 train accuracy: 0.368082 val accuracy: 0.376000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.312204 val accuracy: 0.333000
# lr 5.000000e-07 reg 7.500000e+04 train accuracy: 0.292245 val accuracy: 0.297000
# lr 5.000000e-07 reg 2.500000e+05 train accuracy: 0.246980 val accuracy: 0.257000
# lr 5.000000e-07 reg 7.500000e+05 train accuracy: 0.214306 val accuracy: 0.232000
# lr 5.000000e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-07 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-07 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-07 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-07 reg 2.500000e+00 train accuracy: 0.347000 val accuracy: 0.366000
# lr 9.000000e-07 reg 7.500000e+00 train accuracy: 0.347673 val accuracy: 0.349000
# lr 9.000000e-07 reg 2.500000e+01 train accuracy: 0.351551 val accuracy: 0.336000
# lr 9.000000e-07 reg 7.500000e+01 train accuracy: 0.355939 val accuracy: 0.339000
# lr 9.000000e-07 reg 2.500000e+02 train accuracy: 0.382388 val accuracy: 0.380000
# lr 9.000000e-07 reg 7.500000e+02 train accuracy: 0.401755 val accuracy: 0.413000
# lr 9.000000e-07 reg 2.500000e+03 train accuracy: 0.382082 val accuracy: 0.395000
# lr 9.000000e-07 reg 7.500000e+03 train accuracy: 0.356000 val accuracy: 0.360000
# lr 9.000000e-07 reg 2.500000e+04 train accuracy: 0.319327 val accuracy: 0.334000
# lr 9.000000e-07 reg 7.500000e+04 train accuracy: 0.280714 val accuracy: 0.296000
# lr 9.000000e-07 reg 2.500000e+05 train accuracy: 0.263633 val accuracy: 0.283000
# lr 9.000000e-07 reg 7.500000e+05 train accuracy: 0.211776 val accuracy: 0.219000
# lr 9.000000e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-07 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-07 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-07 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 2.500000e+00 train accuracy: 0.344286 val accuracy: 0.346000
# lr 1.000000e-06 reg 7.500000e+00 train accuracy: 0.350714 val accuracy: 0.330000
# lr 1.000000e-06 reg 2.500000e+01 train accuracy: 0.352959 val accuracy: 0.321000
# lr 1.000000e-06 reg 7.500000e+01 train accuracy: 0.361939 val accuracy: 0.345000
# lr 1.000000e-06 reg 2.500000e+02 train accuracy: 0.387163 val accuracy: 0.396000
# lr 1.000000e-06 reg 7.500000e+02 train accuracy: 0.403041 val accuracy: 0.400000
# lr 1.000000e-06 reg 2.500000e+03 train accuracy: 0.374776 val accuracy: 0.368000
# lr 1.000000e-06 reg 7.500000e+03 train accuracy: 0.355224 val accuracy: 0.358000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.319020 val accuracy: 0.342000
# lr 1.000000e-06 reg 7.500000e+04 train accuracy: 0.296327 val accuracy: 0.312000
# lr 1.000000e-06 reg 2.500000e+05 train accuracy: 0.217245 val accuracy: 0.217000
# lr 1.000000e-06 reg 7.500000e+05 train accuracy: 0.165939 val accuracy: 0.165000
# lr 1.000000e-06 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 2.500000e+00 train accuracy: 0.381408 val accuracy: 0.350000
# lr 5.000000e-06 reg 7.500000e+00 train accuracy: 0.387469 val accuracy: 0.343000
# lr 5.000000e-06 reg 2.500000e+01 train accuracy: 0.393306 val accuracy: 0.393000
# lr 5.000000e-06 reg 7.500000e+01 train accuracy: 0.396429 val accuracy: 0.370000
# lr 5.000000e-06 reg 2.500000e+02 train accuracy: 0.384551 val accuracy: 0.386000
# lr 5.000000e-06 reg 7.500000e+02 train accuracy: 0.339918 val accuracy: 0.326000
# lr 5.000000e-06 reg 2.500000e+03 train accuracy: 0.346510 val accuracy: 0.371000
# lr 5.000000e-06 reg 7.500000e+03 train accuracy: 0.258857 val accuracy: 0.265000
# lr 5.000000e-06 reg 2.500000e+04 train accuracy: 0.179429 val accuracy: 0.184000
# lr 5.000000e-06 reg 7.500000e+04 train accuracy: 0.084714 val accuracy: 0.077000
# lr 5.000000e-06 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 7.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 2.500000e+00 train accuracy: 0.335245 val accuracy: 0.314000
# lr 9.000000e-06 reg 7.500000e+00 train accuracy: 0.394551 val accuracy: 0.356000
# lr 9.000000e-06 reg 2.500000e+01 train accuracy: 0.354082 val accuracy: 0.348000
# lr 9.000000e-06 reg 7.500000e+01 train accuracy: 0.330204 val accuracy: 0.317000
# lr 9.000000e-06 reg 2.500000e+02 train accuracy: 0.272122 val accuracy: 0.269000
# lr 9.000000e-06 reg 7.500000e+02 train accuracy: 0.314714 val accuracy: 0.314000
# lr 9.000000e-06 reg 2.500000e+03 train accuracy: 0.250020 val accuracy: 0.274000
# lr 9.000000e-06 reg 7.500000e+03 train accuracy: 0.168612 val accuracy: 0.187000
# lr 9.000000e-06 reg 2.500000e+04 train accuracy: 0.170918 val accuracy: 0.195000
# lr 9.000000e-06 reg 7.500000e+04 train accuracy: 0.071408 val accuracy: 0.090000
# lr 9.000000e-06 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 7.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 2.500000e+00 train accuracy: 0.352184 val accuracy: 0.343000
# lr 1.000000e-05 reg 7.500000e+00 train accuracy: 0.365857 val accuracy: 0.321000
# lr 1.000000e-05 reg 2.500000e+01 train accuracy: 0.323816 val accuracy: 0.303000
# lr 1.000000e-05 reg 7.500000e+01 train accuracy: 0.260265 val accuracy: 0.258000
# lr 1.000000e-05 reg 2.500000e+02 train accuracy: 0.273245 val accuracy: 0.261000
# lr 1.000000e-05 reg 7.500000e+02 train accuracy: 0.266265 val accuracy: 0.251000
# lr 1.000000e-05 reg 2.500000e+03 train accuracy: 0.250469 val accuracy: 0.278000
# lr 1.000000e-05 reg 7.500000e+03 train accuracy: 0.175408 val accuracy: 0.194000
# lr 1.000000e-05 reg 2.500000e+04 train accuracy: 0.153837 val accuracy: 0.148000
# lr 1.000000e-05 reg 7.500000e+04 train accuracy: 0.099020 val accuracy: 0.101000
# lr 1.000000e-05 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 7.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.500000e+00 train accuracy: 0.320592 val accuracy: 0.310000
# lr 5.000000e-05 reg 7.500000e+00 train accuracy: 0.283224 val accuracy: 0.285000
# lr 5.000000e-05 reg 2.500000e+01 train accuracy: 0.319204 val accuracy: 0.304000
# lr 5.000000e-05 reg 7.500000e+01 train accuracy: 0.257204 val accuracy: 0.251000
# lr 5.000000e-05 reg 2.500000e+02 train accuracy: 0.221673 val accuracy: 0.232000
# lr 5.000000e-05 reg 7.500000e+02 train accuracy: 0.197388 val accuracy: 0.208000
# lr 5.000000e-05 reg 2.500000e+03 train accuracy: 0.162408 val accuracy: 0.175000
# lr 5.000000e-05 reg 7.500000e+03 train accuracy: 0.111327 val accuracy: 0.100000
# lr 5.000000e-05 reg 2.500000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 7.500000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 7.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 2.500000e+00 train accuracy: 0.303673 val accuracy: 0.300000
# lr 9.000000e-05 reg 7.500000e+00 train accuracy: 0.294735 val accuracy: 0.276000
# lr 9.000000e-05 reg 2.500000e+01 train accuracy: 0.244000 val accuracy: 0.224000
# lr 9.000000e-05 reg 7.500000e+01 train accuracy: 0.264327 val accuracy: 0.250000
# lr 9.000000e-05 reg 2.500000e+02 train accuracy: 0.248531 val accuracy: 0.280000
# lr 9.000000e-05 reg 7.500000e+02 train accuracy: 0.165714 val accuracy: 0.166000
# lr 9.000000e-05 reg 2.500000e+03 train accuracy: 0.088796 val accuracy: 0.082000
# lr 9.000000e-05 reg 7.500000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 2.500000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 7.500000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 7.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.413000
# C:\Users\winbaram1000\Desktop\_17멀미\assignment1\cs231n\classifiers\softmax.py:88: RuntimeWarning: divide by zero encountered in log
#   elm_over_sum_scores_exp = scores_exp - sum_scores_exp #(N,C)
# C:\Users\winbaram1000\Desktop\_17멀미\assignment1\cs231n\classifiers\softmax.py:85: RuntimeWarning: overflow encountered in exp
#   correct_scores_exp = scores_exp[np.arange(num_train), y] #(N,1)
# C:\Users\winbaram1000\Desktop\_17멀미\assignment1\cs231n\classifiers\softmax.py:88: RuntimeWarning: invalid value encountered in true_divide
#   elm_over_sum_scores_exp = scores_exp - sum_scores_exp #(N,C)
# C:\Users\winbaram1000\Desktop\_17멀미\assignment1\cs231n\classifiers\softmax.py:89: RuntimeWarning: invalid value encountered in true_divide
#   elm_over_sum_scores_exp[np.arange(num_train), y] = elm_over_sum_scores_exp[np.arange(num_train), y]-1#(N,C)

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.395000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
