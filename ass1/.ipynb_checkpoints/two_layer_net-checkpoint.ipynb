# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()
print(net)
# Out:
# <cs231n.classifiers.neural_net.TwoLayerNet object at 0x000001C112961550>

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027204961e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.79412040779e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b1 max relative error: 2.738423e-09
# b2 max relative error: 3.865039e-11
# W2 max relative error: 3.440708e-09
# W1 max relative error: 3.669858e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function **TwoLayerNet.train** and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the **SVM and Softmax classifiers**. You will also have to **implement TwoLayerNet.predict**, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss **less than 0.2.**

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, **the first layer weights** typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the **loss is decreasing more or less linearly**, which seems to suggest that **the learning rate may be too low**. Moreover, there is **no gap** between the training and validation accuracy, suggesting that the model we used has **low capacity**, and that we **should increase its size**. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including **hidden layer size, learning rate, numer of training epochs, and regularization strength**. You might also consider tuning the **learning rate decay**, but you should be able to get good performance using **the default value**.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than **48%** on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every **1% above 52%** on the Test set we will award you with **one extra bonus point.** Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
results = {}
best_val = -1
learning_rates = [1e-3, 5e-3,
                  1e-2, 5e-2,
                  1e-1, 5e-1
                 ]
regularization_strengths = [
                            2.5e-4, 2.5e-3, 2.5e-2, 2.5e-1,
                            2.5e+0, 2.5e+1, 2.5e+2, 2.5e+3,
                           ]
hidden_sizes = [
    40, 60, 80, 100
]
batch_sizes = [
    50, 200, 800, 3200, 6400
]
input_size = 32 * 32 * 3
num_classes = 10
learning_combs = [(lr,reg,hs,bs) for lr in learning_rates for reg in regularization_strengths for hs in hidden_sizes for bs in batch_sizes]
print('learning_combs size is ', len(learning_combs))
comb_cnt = 0 
for (lr,reg,hs,bs)  in learning_combs:
    hidden_size = bs
    net = TwoLayerNet(input_size, hidden_size, num_classes)
    # Train the network
    stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=int(1000 / (bs/200)), batch_size=bs,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
    # Predict on the validation set
    comb_cnt+=1
    train_accuracy = (net.predict((X_train)) == y_train).mean()
    val_accuracy = (net.predict(X_val) == y_val).mean()
    print('Validation accuracy: ', val_accuracy, '(%d/%d done)'%(comb_cnt,len(learning_combs)))
    results[(lr, reg, hs, bs)] = (train_accuracy, val_accuracy, stats)
    if(val_accuracy > best_val):
        best_val = val_accuracy
        best_net = net

#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# learning_combs size is  960
# Validation accuracy:  0.459 (1/960 done)
# Validation accuracy:  0.488 (2/960 done)
# Validation accuracy:  0.44 (3/960 done)
# Validation accuracy:  0.311 (4/960 done)
# Validation accuracy:  0.274 (5/960 done)
# Validation accuracy:  0.458 (6/960 done)
# Validation accuracy:  0.504 (7/960 done)
# Validation accuracy:  0.43 (8/960 done)
# Validation accuracy:  0.303 (9/960 done)
# Validation accuracy:  0.273 (10/960 done)
# Validation accuracy:  0.49 (11/960 done)
# Validation accuracy:  0.491 (12/960 done)
# Validation accuracy:  0.427 (13/960 done)
# Validation accuracy:  0.312 (14/960 done)
# Validation accuracy:  0.276 (15/960 done)
# Validation accuracy:  0.475 (16/960 done)
# Validation accuracy:  0.491 (17/960 done)
# Validation accuracy:  0.427 (18/960 done)
# Validation accuracy:  0.308 (19/960 done)
# Validation accuracy:  0.274 (20/960 done)
# Validation accuracy:  0.47 (21/960 done)
# Validation accuracy:  0.495 (22/960 done)
# Validation accuracy:  0.436 (23/960 done)
# Validation accuracy:  0.312 (24/960 done)
# Validation accuracy:  0.28 (25/960 done)
# Validation accuracy:  0.484 (26/960 done)
# Validation accuracy:  0.489 (27/960 done)
# Validation accuracy:  0.444 (28/960 done)
# Validation accuracy:  0.307 (29/960 done)
# Validation accuracy:  0.278 (30/960 done)
# Validation accuracy:  0.476 (31/960 done)
# Validation accuracy:  0.493 (32/960 done)
# Validation accuracy:  0.437 (33/960 done)
# Validation accuracy:  0.307 (34/960 done)
# Validation accuracy:  0.275 (35/960 done)
# Validation accuracy:  0.461 (36/960 done)
# Validation accuracy:  0.503 (37/960 done)
# Validation accuracy:  0.441 (38/960 done)
# Validation accuracy:  0.311 (39/960 done)
# Validation accuracy:  0.272 (40/960 done)
# Validation accuracy:  0.454 (41/960 done)
# Validation accuracy:  0.499 (42/960 done)
# Validation accuracy:  0.425 (43/960 done)
# Validation accuracy:  0.313 (44/960 done)
# Validation accuracy:  0.276 (45/960 done)
# Validation accuracy:  0.467 (46/960 done)
# Validation accuracy:  0.479 (47/960 done)
# Validation accuracy:  0.424 (48/960 done)
# Validation accuracy:  0.314 (49/960 done)
# Validation accuracy:  0.274 (50/960 done)
# Validation accuracy:  0.47 (51/960 done)
# Validation accuracy:  0.489 (52/960 done)
# Validation accuracy:  0.429 (53/960 done)
# Validation accuracy:  0.306 (54/960 done)
# Validation accuracy:  0.265 (55/960 done)
# Validation accuracy:  0.468 (56/960 done)
# Validation accuracy:  0.48 (57/960 done)
# Validation accuracy:  0.423 (58/960 done)
# Validation accuracy:  0.31 (59/960 done)
# Validation accuracy:  0.27 (60/960 done)
# Validation accuracy:  0.447 (61/960 done)
# Validation accuracy:  0.493 (62/960 done)
# Validation accuracy:  0.434 (63/960 done)
# Validation accuracy:  0.313 (64/960 done)
# Validation accuracy:  0.273 (65/960 done)
# Validation accuracy:  0.48 (66/960 done)
# Validation accuracy:  0.497 (67/960 done)
# Validation accuracy:  0.414 (68/960 done)
# Validation accuracy:  0.307 (69/960 done)
# Validation accuracy:  0.269 (70/960 done)
# Validation accuracy:  0.462 (71/960 done)
# Validation accuracy:  0.469 (72/960 done)
# Validation accuracy:  0.427 (73/960 done)
# Validation accuracy:  0.306 (74/960 done)
# Validation accuracy:  0.27 (75/960 done)
# Validation accuracy:  0.468 (76/960 done)
# Validation accuracy:  0.488 (77/960 done)
# Validation accuracy:  0.432 (78/960 done)
# Validation accuracy:  0.311 (79/960 done)
# Validation accuracy:  0.275 (80/960 done)
# Validation accuracy:  0.408 (81/960 done)
# Validation accuracy:  0.446 (82/960 done)
# Validation accuracy:  0.386 (83/960 done)
# Validation accuracy:  0.298 (84/960 done)
# Validation accuracy:  0.259 (85/960 done)
# Validation accuracy:  0.424 (86/960 done)
# Validation accuracy:  0.443 (87/960 done)
# Validation accuracy:  0.395 (88/960 done)
# Validation accuracy:  0.304 (89/960 done)
# Validation accuracy:  0.266 (90/960 done)
# Validation accuracy:  0.409 (91/960 done)
# Validation accuracy:  0.449 (92/960 done)
# Validation accuracy:  0.394 (93/960 done)
# Validation accuracy:  0.304 (94/960 done)
# Validation accuracy:  0.273 (95/960 done)
# Validation accuracy:  0.435 (96/960 done)
# Validation accuracy:  0.451 (97/960 done)
# Validation accuracy:  0.396 (98/960 done)
# Validation accuracy:  0.301 (99/960 done)
# Validation accuracy:  0.265 (100/960 done)
# Validation accuracy:  0.248 (101/960 done)
# Validation accuracy:  0.267 (102/960 done)
# Validation accuracy:  0.249 (103/960 done)
# Validation accuracy:  0.22 (104/960 done)
# Validation accuracy:  0.211 (105/960 done)
# Validation accuracy:  0.211 (106/960 done)
# Validation accuracy:  0.257 (107/960 done)
# Validation accuracy:  0.236 (108/960 done)
# Validation accuracy:  0.227 (109/960 done)
# Validation accuracy:  0.209 (110/960 done)
# Validation accuracy:  0.21 (111/960 done)
# Validation accuracy:  0.256 (112/960 done)
# Validation accuracy:  0.255 (113/960 done)
# Validation accuracy:  0.226 (114/960 done)
# Validation accuracy:  0.213 (115/960 done)
# Validation accuracy:  0.249 (116/960 done)
# Validation accuracy:  0.257 (117/960 done)
# Validation accuracy:  0.236 (118/960 done)
# Validation accuracy:  0.225 (119/960 done)
# Validation accuracy:  0.205 (120/960 done)
# Validation accuracy:  0.078 (121/960 done)
# Validation accuracy:  0.087 (122/960 done)
# Validation accuracy:  0.105 (123/960 done)
# Validation accuracy:  0.102 (124/960 done)
# Validation accuracy:  0.098 (125/960 done)
# Validation accuracy:  0.102 (126/960 done)
# Validation accuracy:  0.079 (127/960 done)
# Validation accuracy:  0.098 (128/960 done)
# Validation accuracy:  0.105 (129/960 done)
# Validation accuracy:  0.098 (130/960 done)
# Validation accuracy:  0.112 (131/960 done)
# Validation accuracy:  0.105 (132/960 done)
# Validation accuracy:  0.119 (133/960 done)
# Validation accuracy:  0.087 (134/960 done)
# Validation accuracy:  0.102 (135/960 done)
# Validation accuracy:  0.098 (136/960 done)
# Validation accuracy:  0.087 (137/960 done)
# Validation accuracy:  0.112 (138/960 done)
# Validation accuracy:  0.087 (139/960 done)
# Validation accuracy:
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\neural_net.py:104: RuntimeWarning: divide by zero encountered in log
#   loss = np.sum(-np.log( correct_scores_exp / sum_scores_exp))
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\neural_net.py:101: RuntimeWarning: overflow encountered in exp
#   scores_exp = np.exp(scores) #(N,C)
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\neural_net.py:104: RuntimeWarning: invalid value encountered in true_divide
#   loss = np.sum(-np.log( correct_scores_exp / sum_scores_exp))
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\neural_net.py:123: RuntimeWarning: invalid value encountered in true_divide
#   elm_over_sum_scores_exp = scores_exp / np.reshape(sum_scores_exp, (N, 1))#(N,C)
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\neural_net.py:82: RuntimeWarning: invalid value encountered in less_equal
#   H_mask[H<=0] = 0
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\neural_net.py:83: RuntimeWarning: invalid value encountered in less_equal
#   H[H<=0] = 0 #maximum(H,0)
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\neural_net.py:245: RuntimeWarning: invalid value encountered in maximum
#   H = np.maximum( np.dot(X,W1) + b1, 0)    #(N,H)   same as H[H<=0] = 0 #maximum(H,0)
#  0.078 (140/960 done)
# Validation accuracy:  0.087 (141/960 done)
# Validation accuracy:  0.087 (142/960 done)
# Validation accuracy:  0.087 (143/960 done)
# Validation accuracy:  0.087 (144/960 done)
# Validation accuracy:  0.087 (145/960 done)
# Validation accuracy:  0.087 (146/960 done)
# Validation accuracy:  0.087 (147/960 done)
# Validation accuracy:  0.087 (148/960 done)
# Validation accuracy:  0.087 (149/960 done)
# Validation accuracy:  0.087 (150/960 done)
# Validation accuracy:  0.087 (151/960 done)
# Validation accuracy:  0.087 (152/960 done)
# Validation accuracy:  0.087 (153/960 done)
# Validation accuracy:  0.087 (154/960 done)
# Validation accuracy:  0.087 (155/960 done)
# Validation accuracy:  0.087 (156/960 done)
# Validation accuracy:  0.087 (157/960 done)
# Validation accuracy:  0.087 (158/960 done)
# Validation accuracy:  0.087 (159/960 done)
# Validation accuracy:  0.087 (160/960 done)
# Validation accuracy:  0.087 (161/960 done)
# Validation accuracy:  0.087 (162/960 done)
# Validation accuracy:  0.087 (163/960 done)
# Validation accuracy:  0.393 (164/960 done)
# Validation accuracy:  0.337 (165/960 done)
# Validation accuracy:  0.087 (166/960 done)
# Validation accuracy:  0.087 (167/960 done)
# Validation accuracy:  0.087 (168/960 done)
# Validation accuracy:  0.312 (169/960 done)
# Validation accuracy:  0.344 (170/960 done)
# Validation accuracy:  0.087 (171/960 done)
# Validation accuracy:  0.087 (172/960 done)
# Validation accuracy:  0.087 (173/960 done)
# Validation accuracy:  0.321 (174/960 done)
# Validation accuracy:  0.336 (175/960 done)
# Validation accuracy:  0.087 (176/960 done)
# Validation accuracy:  0.087 (177/960 done)
# Validation accuracy:  0.087 (178/960 done)
# Validation accuracy:  0.378 (179/960 done)
# Validation accuracy:  0.323 (180/960 done)
# Validation accuracy:  0.087 (181/960 done)
# Validation accuracy:  0.087 (182/960 done)
# Validation accuracy:  0.087 (183/960 done)
# Validation accuracy:  0.384 (184/960 done)
# Validation accuracy:  0.321 (185/960 done)
# Validation accuracy:  0.087 (186/960 done)
# Validation accuracy:  0.087 (187/960 done)
# Validation accuracy:  0.087 (188/960 done)
# Validation accuracy:  0.399 (189/960 done)
# Validation accuracy:  0.359 (190/960 done)
# Validation accuracy:  0.087 (191/960 done)
# Validation accuracy:  0.087 (192/960 done)
# Validation accuracy:  0.087 (193/960 done)
# Validation accuracy:  0.243 (194/960 done)
# Validation accuracy:  0.31 (195/960 done)
# Validation accuracy:  0.087 (196/960 done)
# Validation accuracy:  0.087 (197/960 done)
# Validation accuracy:  0.087 (198/960 done)
# Validation accuracy:  0.345 (199/960 done)
# Validation accuracy:  0.377 (200/960 done)
# Validation accuracy:  0.087 (201/960 done)
# Validation accuracy:  0.087 (202/960 done)
# Validation accuracy:  0.087 (203/960 done)
# Validation accuracy:  0.382 (204/960 done)
# Validation accuracy:  0.366 (205/960 done)
# Validation accuracy:  0.087 (206/960 done)
# Validation accuracy:  0.087 (207/960 done)
# Validation accuracy:  0.087 (208/960 done)
# Validation accuracy:  0.373 (209/960 done)
# Validation accuracy:  0.365 (210/960 done)
# Validation accuracy:  0.087 (211/960 done)
# Validation accuracy:  0.087 (212/960 done)
# Validation accuracy:  0.087 (213/960 done)
# Validation accuracy:  0.259 (214/960 done)
# Validation accuracy:  0.314 (215/960 done)
# Validation accuracy:  0.087 (216/960 done)
# Validation accuracy:  0.087 (217/960 done)
# Validation accuracy:  0.087 (218/960 done)
# Validation accuracy:  0.36 (219/960 done)
# Validation accuracy:  0.35 (220/960 done)
# Validation accuracy:  0.087 (221/960 done)
# Validation accuracy:  0.087 (222/960 done)
# Validation accuracy:  0.087 (223/960 done)
# Validation accuracy:  0.388 (224/960 done)
# Validation accuracy:  0.363 (225/960 done)
# Validation accuracy:  0.087 (226/960 done)
# Validation accuracy:  0.087 (227/960 done)
# Validation accuracy:  0.087 (228/960 done)
# Validation accuracy:  0.293 (229/960 done)
# Validation accuracy:  0.337 (230/960 done)
# Validation accuracy:  0.087 (231/960 done)
# Validation accuracy:  0.087 (232/960 done)
# Validation accuracy:  0.087 (233/960 done)
# Validation accuracy:  0.322 (234/960 done)
# Validation accuracy:  0.35 (235/960 done)
# Validation accuracy:  0.087 (236/960 done)
# Validation accuracy:  0.087 (237/960 done)
# Validation accuracy:  0.087 (238/960 done)
# Validation accuracy:  0.359 (239/960 done)
# Validation accuracy:  0.361 (240/960 done)
# Validation accuracy:  0.087 (241/960 done)
# Validation accuracy:  0.087 (242/960 done)
# Validation accuracy:  0.087 (243/960 done)
# Validation accuracy:  0.365 (244/960 done)
# Validation accuracy:  0.36 (245/960 done)
# Validation accuracy:  0.087 (246/960 done)
# Validation accuracy:  0.087 (247/960 done)
# Validation accuracy:  0.335 (248/960 done)
# Validation accuracy:  0.384 (249/960 done)
# Validation accuracy:  0.319 (250/960 done)
# Validation accuracy:  0.087 (251/960 done)
# Validation accuracy:  0.087 (252/960 done)
# Validation accuracy:  0.355 (253/960 done)
# Validation accuracy:  0.332 (254/960 done)
# Validation accuracy:  0.303 (255/960 done)
# Validation accuracy:  0.087 (256/960 done)
# Validation accuracy:  0.087 (257/960 done)
# Validation accuracy:  0.384 (258/960 done)
# Validation accuracy:  0.378 (259/960 done)
# Validation accuracy:  0.363 (260/960 done)
# Validation accuracy:  0.087 (261/960 done)
# Validation accuracy:  0.229 (262/960 done)
# Validation accuracy:  0.262 (263/960 done)
# Validation accuracy:  0.255 (264/960 done)
# Validation accuracy:  0.236 (265/960 done)
# Validation accuracy:  0.087 (266/960 done)
# Validation accuracy:  0.239 (267/960 done)
# Validation accuracy:  0.246 (268/960 done)
# Validation accuracy:  0.249 (269/960 done)
# Validation accuracy:  0.254 (270/960 done)
# Validation accuracy:  0.087 (271/960 done)
# Validation accuracy:  0.187 (272/960 done)
# Validation accuracy:  0.256 (273/960 done)
# Validation accuracy:  0.256 (274/960 done)
# Validation accuracy:  0.25 (275/960 done)
# Validation accuracy:  0.087 (276/960 done)
# Validation accuracy:  0.243 (277/960 done)
# Validation accuracy:  0.251 (278/960 done)
# Validation accuracy:  0.248 (279/960 done)
# Validation accuracy:  0.243 (280/960 done)
# Validation accuracy:  0.087 (281/960 done)
# Validation accuracy:  0.087 (282/960 done)
# Validation accuracy:  0.087 (283/960 done)
# Validation accuracy:  0.087 (284/960 done)
# Validation accuracy:  0.087 (285/960 done)
# Validation accuracy:  0.087 (286/960 done)
# Validation accuracy:  0.087 (287/960 done)
# Validation accuracy:  0.087 (288/960 done)
# Validation accuracy:  0.087 (289/960 done)
# Validation accuracy:  0.087 (290/960 done)
# Validation accuracy:  0.087 (291/960 done)
# Validation accuracy:  0.087 (292/960 done)
# Validation accuracy:  0.087 (293/960 done)
# Validation accuracy:  0.087 (294/960 done)
# Validation accuracy:  0.087 (295/960 done)
# Validation accuracy:  0.087 (296/960 done)
# Validation accuracy:  0.087 (297/960 done)
# Validation accuracy:  0.087 (298/960 done)
# Validation accuracy:  0.087 (299/960 done)
# Validation accuracy:  0.087 (300/960 done)
# Validation accuracy:  0.087 (301/960 done)
# Validation accuracy:  0.087 (302/960 done)
# Validation accuracy:  0.087 (303/960 done)
# Validation accuracy:  0.087 (304/960 done)
# Validation accuracy:  0.087 (305/960 done)
# Validation accuracy:  0.087 (306/960 done)
# Validation accuracy:  0.087 (307/960 done)
# Validation accuracy:  0.087 (308/960 done)
# Validation accuracy:  0.087 (309/960 done)
# Validation accuracy:  0.087 (310/960 done)
# Validation accuracy:  0.087 (311/960 done)
# Validation accuracy:  0.087 (312/960 done)
# Validation accuracy:  0.087 (313/960 done)
# Validation accuracy:  0.087 (314/960 done)
# Validation accuracy:  0.087 (315/960 done)
# Validation accuracy:  0.087 (316/960 done)
# Validation accuracy:  0.087 (317/960 done)
# Validation accuracy:  0.087 (318/960 done)
# Validation accuracy:  0.087 (319/960 done)
# Validation accuracy:  0.087 (320/960 done)
# Validation accuracy:  0.087 (321/960 done)
# Validation accuracy:  0.087 (322/960 done)
# Validation accuracy:  0.087 (323/960 done)
# Validation accuracy:  0.087 (324/960 done)
# Validation accuracy:  0.087 (325/960 done)
# Validation accuracy:  0.087 (326/960 done)
# Validation accuracy:  0.087 (327/960 done)
# Validation accuracy:  0.087 (328/960 done)
# Validation accuracy:  0.087 (329/960 done)
# Validation accuracy:  0.087 (330/960 done)
# Validation accuracy:  0.087 (331/960 done)
# Validation accuracy:  0.087 (332/960 done)
# Validation accuracy:  0.087 (333/960 done)
# Validation accuracy:  0.087 (334/960 done)
# Validation accuracy:  0.087 (335/960 done)
# Validation accuracy:  0.087 (336/960 done)
# Validation accuracy:  0.087 (337/960 done)
# Validation accuracy:  0.087 (338/960 done)
# Validation accuracy:  0.087 (339/960 done)
# Validation accuracy:  0.087 (340/960 done)
# Validation accuracy:  0.087 (341/960 done)
# Validation accuracy:  0.087 (342/960 done)
# Validation accuracy:  0.087 (343/960 done)
# Validation accuracy:  0.087 (344/960 done)
# Validation accuracy:  0.087 (345/960 done)
# Validation accuracy:  0.087 (346/960 done)
# Validation accuracy:  0.087 (347/960 done)
# Validation accuracy:  0.087 (348/960 done)
# Validation accuracy:  0.087 (349/960 done)
# Validation accuracy:  0.087 (350/960 done)
# Validation accuracy:  0.087 (351/960 done)
# Validation accuracy:  0.087 (352/960 done)
# Validation accuracy:  0.087 (353/960 done)
# Validation accuracy:  0.087 (354/960 done)
# Validation accuracy:  0.087 (355/960 done)
# Validation accuracy:  0.087 (356/960 done)
# Validation accuracy:  0.087 (357/960 done)
# Validation accuracy:  0.087 (358/960 done)
# Validation accuracy:  0.087 (359/960 done)
# Validation accuracy:  0.087 (360/960 done)
# Validation accuracy:  0.087 (361/960 done)
# Validation accuracy:  0.087 (362/960 done)
# Validation accuracy:  0.087 (363/960 done)
# Validation accuracy:  0.087 (364/960 done)
# Validation accuracy:  0.087 (365/960 done)
# Validation accuracy:  0.087 (366/960 done)
# Validation accuracy:  0.087 (367/960 done)
# Validation accuracy:  0.087 (368/960 done)
# Validation accuracy:  0.087 (369/960 done)
# Validation accuracy:  0.087 (370/960 done)
# Validation accuracy:  0.087 (371/960 done)
# Validation accuracy:  0.087 (372/960 done)
# Validation accuracy:  0.087 (373/960 done)
# Validation accuracy:  0.087 (374/960 done)
# Validation accuracy:  0.087 (375/960 done)
# Validation accuracy:  0.087 (376/960 done)
# Validation accuracy:  0.087 (377/960 done)
# Validation accuracy:  0.087 (378/960 done)
# Validation accuracy:  0.087 (379/960 done)
# Validation accuracy:  0.087 (380/960 done)
# Validation accuracy:  0.087 (381/960 done)
# Validation accuracy:  0.087 (382/960 done)
# Validation accuracy:  0.087 (383/960 done)
# Validation accuracy:  0.087 (384/960 done)
# Validation accuracy:  0.087 (385/960 done)
# Validation accuracy:  0.087 (386/960 done)
# Validation accuracy:  0.087 (387/960 done)
# Validation accuracy:  0.087 (388/960 done)
# Validation accuracy:  0.087 (389/960 done)
# Validation accuracy:  0.087 (390/960 done)
# Validation accuracy:  0.087 (391/960 done)
# Validation accuracy:  0.087 (392/960 done)
# Validation accuracy:  0.087 (393/960 done)
# Validation accuracy:  0.087 (394/960 done)
# Validation accuracy:  0.087 (395/960 done)
# Validation accuracy:  0.087 (396/960 done)
# Validation accuracy:  0.087 (397/960 done)
# Validation accuracy:  0.087 (398/960 done)
# Validation accuracy:  0.087 (399/960 done)
# Validation accuracy:  0.087 (400/960 done)
# Validation accuracy:  0.087 (401/960 done)
# Validation accuracy:  0.087 (402/960 done)
# Validation accuracy:  0.087 (403/960 done)
# Validation accuracy:  0.087 (404/960 done)
# Validation accuracy:  0.087 (405/960 done)
# Validation accuracy:  0.087 (406/960 done)
# Validation accuracy:  0.087 (407/960 done)
# Validation accuracy:  0.087 (408/960 done)
# Validation accuracy:  0.087 (409/960 done)
# Validation accuracy:  0.087 (410/960 done)
# Validation accuracy:  0.087 (411/960 done)
# Validation accuracy:  0.087 (412/960 done)
# Validation accuracy:  0.087 (413/960 done)
# Validation accuracy:  0.087 (414/960 done)
# Validation accuracy:  0.087 (415/960 done)
# Validation accuracy:  0.087 (416/960 done)
# Validation accuracy:  0.087 (417/960 done)
# Validation accuracy:  0.087 (418/960 done)
# Validation accuracy:  0.087 (419/960 done)
# Validation accuracy:  0.087 (420/960 done)
# Validation accuracy:  0.087 (421/960 done)
# Validation accuracy:  0.087 (422/960 done)
# Validation accuracy:  0.087 (423/960 done)
# Validation accuracy:  0.087 (424/960 done)
# Validation accuracy:  0.194 (425/960 done)
# Validation accuracy:  0.087 (426/960 done)
# Validation accuracy:  0.087 (427/960 done)
# Validation accuracy:  0.087 (428/960 done)
# Validation accuracy:  0.087 (429/960 done)
# Validation accuracy:  0.087 (430/960 done)
# Validation accuracy:  0.087 (431/960 done)
# Validation accuracy:  0.087 (432/960 done)
# Validation accuracy:  0.087 (433/960 done)
# Validation accuracy:  0.179 (434/960 done)
# Validation accuracy:  0.15 (435/960 done)
# Validation accuracy:  0.087 (436/960 done)
# Validation accuracy:  0.087 (437/960 done)
# Validation accuracy:  0.087 (438/960 done)
# Validation accuracy:  0.205 (439/960 done)
# Validation accuracy:  0.237 (440/960 done)
# Validation accuracy:  0.087 (441/960 done)
# Validation accuracy:  0.087 (442/960 done)
# Validation accuracy:  0.087 (443/960 done)
# Validation accuracy:  0.087 (444/960 done)
# Validation accuracy:  0.087 (445/960 done)
# Validation accuracy:  0.087 (446/960 done)
# Validation accuracy:  0.087 (447/960 done)
# Validation accuracy:  0.087 (448/960 done)
# Validation accuracy:  0.087 (449/960 done)
# Validation accuracy:  0.087 (450/960 done)
# Validation accuracy:  0.087 (451/960 done)
# Validation accuracy:  0.087 (452/960 done)
# Validation accuracy:  0.087 (453/960 done)
# Validation accuracy:  0.087 (454/960 done)
# Validation accuracy:  0.087 (455/960 done)
# Validation accuracy:  0.087 (456/960 done)
# Validation accuracy:  0.087 (457/960 done)
# Validation accuracy:  0.087 (458/960 done)
# Validation accuracy:  0.087 (459/960 done)
# Validation accuracy:  0.087 (460/960 done)
# Validation accuracy:  0.087 (461/960 done)
# Validation accuracy:  0.087 (462/960 done)
# Validation accuracy:  0.087 (463/960 done)
# Validation accuracy:  0.087 (464/960 done)
# Validation accuracy:  0.087 (465/960 done)
# Validation accuracy:  0.087 (466/960 done)
# Validation accuracy:  0.087 (467/960 done)
# Validation accuracy:  0.087 (468/960 done)
# Validation accuracy:  0.087 (469/960 done)
# Validation accuracy:  0.087 (470/960 done)
# Validation accuracy:  0.087 (471/960 done)
# Validation accuracy:  0.087 (472/960 done)
# Validation accuracy:  0.087 (473/960 done)
# Validation accuracy:  0.087 (474/960 done)
# Validation accuracy:  0.087 (475/960 done)
# Validation accuracy:  0.087 (476/960 done)
# Validation accuracy:  0.087 (477/960 done)
# Validation accuracy:  0.087 (478/960 done)
# Validation accuracy:  0.087 (479/960 done)
# Validation accuracy:  0.087 (480/960 done)
# Validation accuracy:  0.087 (481/960 done)
# Validation accuracy:  0.087 (482/960 done)
# Validation accuracy:  0.087 (483/960 done)
# Validation accuracy:  0.087 (484/960 done)
# Validation accuracy:  0.087 (485/960 done)
# Validation accuracy:  0.087 (486/960 done)
# Validation accuracy:  0.087 (487/960 done)
# Validation accuracy:  0.087 (488/960 done)
# Validation accuracy:  0.087 (489/960 done)
# Validation accuracy:  0.087 (490/960 done)
# Validation accuracy:  0.087 (491/960 done)
# Validation accuracy:  0.087 (492/960 done)
# Validation accuracy:  0.087 (493/960 done)
# Validation accuracy:  0.087 (494/960 done)
# Validation accuracy:  0.087 (495/960 done)
# Validation accuracy:  0.087 (496/960 done)
# Validation accuracy:  0.087 (497/960 done)
# Validation accuracy:  0.087 (498/960 done)
# Validation accuracy:  0.087 (499/960 done)
# Validation accuracy:  0.087 (500/960 done)
# Validation accuracy:  0.087 (501/960 done)
# Validation accuracy:  0.087 (502/960 done)
# Validation accuracy:  0.087 (503/960 done)
# Validation accuracy:  0.087 (504/960 done)
# Validation accuracy:  0.087 (505/960 done)
# Validation accuracy:  0.087 (506/960 done)
# Validation accuracy:  0.087 (507/960 done)
# Validation accuracy:  0.087 (508/960 done)
# Validation accuracy:  0.087 (509/960 done)
# Validation accuracy:  0.087 (510/960 done)
# Validation accuracy:  0.087 (511/960 done)
# Validation accuracy:  0.087 (512/960 done)
# Validation accuracy:  0.087 (513/960 done)
# Validation accuracy:  0.087 (514/960 done)
# Validation accuracy:  0.087 (515/960 done)
# Validation accuracy:  0.087 (516/960 done)
# Validation accuracy:  0.087 (517/960 done)
# Validation accuracy:  0.087 (518/960 done)
# Validation accuracy:  0.087 (519/960 done)
# Validation accuracy:  0.087 (520/960 done)
# Validation accuracy:  0.087 (521/960 done)
# Validation accuracy:  0.087 (522/960 done)
# Validation accuracy:  0.087 (523/960 done)
# Validation accuracy:  0.087 (524/960 done)
# Validation accuracy:  0.087 (525/960 done)
# Validation accuracy:  0.087 (526/960 done)
# Validation accuracy:  0.087 (527/960 done)
# Validation accuracy:  0.087 (528/960 done)
# Validation accuracy:  0.087 (529/960 done)
# Validation accuracy:  0.087 (530/960 done)
# Validation accuracy:  0.087 (531/960 done)
# Validation accuracy:  0.087 (532/960 done)
# Validation accuracy:  0.087 (533/960 done)
# Validation accuracy:  0.087 (534/960 done)
# Validation accuracy:  0.087 (535/960 done)
# Validation accuracy:  0.087 (536/960 done)
# Validation accuracy:  0.087 (537/960 done)
# Validation accuracy:  0.087 (538/960 done)
# Validation accuracy:  0.087 (539/960 done)
# Validation accuracy:  0.087 (540/960 done)
# Validation accuracy:  0.087 (541/960 done)
# Validation accuracy:  0.087 (542/960 done)
# Validation accuracy:  0.087 (543/960 done)
# Validation accuracy:  0.087 (544/960 done)
# Validation accuracy:  0.087 (545/960 done)
# Validation accuracy:  0.087 (546/960 done)
# Validation accuracy:  0.087 (547/960 done)
# Validation accuracy:  0.087 (548/960 done)
# Validation accuracy:  0.087 (549/960 done)
# Validation accuracy:  0.087 (550/960 done)
# Validation accuracy:  0.087 (551/960 done)
# Validation accuracy:  0.087 (552/960 done)
# Validation accuracy:  0.087 (553/960 done)
# Validation accuracy:  0.087 (554/960 done)
# Validation accuracy:  0.087 (555/960 done)
# Validation accuracy:  0.087 (556/960 done)
# Validation accuracy:  0.087 (557/960 done)
# Validation accuracy:  0.087 (558/960 done)
# Validation accuracy:  0.087 (559/960 done)
# Validation accuracy:  0.087 (560/960 done)
# Validation accuracy:  0.087 (561/960 done)
# Validation accuracy:  0.087 (562/960 done)
# Validation accuracy:  0.087 (563/960 done)
# Validation accuracy:  0.087 (564/960 done)
# Validation accuracy:  0.087 (565/960 done)
# Validation accuracy:  0.087 (566/960 done)
# Validation accuracy:  0.087 (567/960 done)
# Validation accuracy:  0.087 (568/960 done)
# Validation accuracy:  0.087 (569/960 done)
# Validation accuracy:  0.087 (570/960 done)
# Validation accuracy:  0.087 (571/960 done)
# Validation accuracy:  0.087 (572/960 done)
# Validation accuracy:  0.087 (573/960 done)
# Validation accuracy:  0.087 (574/960 done)
# Validation accuracy:  0.087 (575/960 done)
# Validation accuracy:  0.087 (576/960 done)
# Validation accuracy:  0.087 (577/960 done)
# Validation accuracy:  0.087 (578/960 done)
# Validation accuracy:  0.087 (579/960 done)
# Validation accuracy:  0.087 (580/960 done)
# Validation accuracy:  0.087 (581/960 done)
# Validation accuracy:  0.087 (582/960 done)
# Validation accuracy:  0.087 (583/960 done)
# Validation accuracy:  0.087 (584/960 done)
# Validation accuracy:  0.087 (585/960 done)
# Validation accuracy:  0.087 (586/960 done)
# Validation accuracy:  0.087 (587/960 done)
# Validation accuracy:  0.087 (588/960 done)
# Validation accuracy:  0.087 (589/960 done)
# Validation accuracy:  0.087 (590/960 done)
# Validation accuracy:  0.087 (591/960 done)
# Validation accuracy:  0.087 (592/960 done)
# Validation accuracy:  0.087 (593/960 done)
# Validation accuracy:  0.087 (594/960 done)
# Validation accuracy:  0.087 (595/960 done)
# Validation accuracy:  0.087 (596/960 done)
# Validation accuracy:  0.087 (597/960 done)
# Validation accuracy:  0.087 (598/960 done)
# Validation accuracy:  0.087 (599/960 done)
# Validation accuracy:  0.087 (600/960 done)
# Validation accuracy:  0.087 (601/960 done)
# Validation accuracy:  0.087 (602/960 done)
# Validation accuracy:  0.087 (603/960 done)
# Validation accuracy:  0.087 (604/960 done)
# Validation accuracy:  0.087 (605/960 done)
# Validation accuracy:  0.087 (606/960 done)
# Validation accuracy:  0.087 (607/960 done)
# Validation accuracy:  0.087 (608/960 done)
# Validation accuracy:  0.087 (609/960 done)
# Validation accuracy:  0.087 (610/960 done)
# Validation accuracy:  0.087 (611/960 done)
# Validation accuracy:  0.087 (612/960 done)
# Validation accuracy:  0.087 (613/960 done)
# Validation accuracy:  0.087 (614/960 done)
# Validation accuracy:  0.087 (615/960 done)
# Validation accuracy:  0.087 (616/960 done)
# Validation accuracy:  0.087 (617/960 done)
# Validation accuracy:  0.087 (618/960 done)
# Validation accuracy:  0.087 (619/960 done)
# Validation accuracy:  0.087 (620/960 done)
# Validation accuracy:  0.087 (621/960 done)
# Validation accuracy:  0.087 (622/960 done)
# Validation accuracy:  0.087 (623/960 done)
# Validation accuracy:  0.087 (624/960 done)
# Validation accuracy:  0.087 (625/960 done)
# Validation accuracy:  0.087 (626/960 done)
# Validation accuracy:  0.087 (627/960 done)
# Validation accuracy:  0.087 (628/960 done)
# Validation accuracy:  0.087 (629/960 done)
# Validation accuracy:  0.087 (630/960 done)
# Validation accuracy:  0.087 (631/960 done)
# Validation accuracy:  0.087 (632/960 done)
# Validation accuracy:  0.087 (633/960 done)
# Validation accuracy:  0.087 (634/960 done)
# Validation accuracy:  0.087 (635/960 done)
# Validation accuracy:  0.087 (636/960 done)
# Validation accuracy:  0.087 (637/960 done)
# Validation accuracy:  0.087 (638/960 done)
# Validation accuracy:  0.087 (639/960 done)
# Validation accuracy:  0.087 (640/960 done)
# Validation accuracy:  0.087 (641/960 done)
# Validation accuracy:  0.087 (642/960 done)
# Validation accuracy:  0.087 (643/960 done)
# Validation accuracy:  0.087 (644/960 done)
# Validation accuracy:  0.087 (645/960 done)
# Validation accuracy:  0.087 (646/960 done)
# Validation accuracy:  0.087 (647/960 done)
# Validation accuracy:  0.087 (648/960 done)
# Validation accuracy:  0.087 (649/960 done)
# Validation accuracy:  0.087 (650/960 done)
# Validation accuracy:  0.087 (651/960 done)
# Validation accuracy:  0.087 (652/960 done)
# Validation accuracy:  0.087 (653/960 done)
# Validation accuracy:  0.087 (654/960 done)
# Validation accuracy:  0.087 (655/960 done)
# Validation accuracy:  0.087 (656/960 done)
# Validation accuracy:  0.087 (657/960 done)
# Validation accuracy:  0.087 (658/960 done)
# Validation accuracy:  0.087 (659/960 done)
# Validation accuracy:  0.087 (660/960 done)
# Validation accuracy:  0.087 (661/960 done)
# Validation accuracy:  0.087 (662/960 done)
# Validation accuracy:  0.087 (663/960 done)
# Validation accuracy:  0.087 (664/960 done)
# Validation accuracy:  0.087 (665/960 done)
# Validation accuracy:  0.087 (666/960 done)
# Validation accuracy:  0.087 (667/960 done)
# Validation accuracy:  0.087 (668/960 done)
# Validation accuracy:  0.087 (669/960 done)
# Validation accuracy:  0.087 (670/960 done)
# Validation accuracy:  0.087 (671/960 done)
# Validation accuracy:  0.087 (672/960 done)
# Validation accuracy:  0.087 (673/960 done)
# Validation accuracy:  0.087 (674/960 done)
# Validation accuracy:  0.087 (675/960 done)
# Validation accuracy:  0.087 (676/960 done)
# Validation accuracy:  0.087 (677/960 done)
# Validation accuracy:  0.087 (678/960 done)
# Validation accuracy:  0.087 (679/960 done)
# Validation accuracy:  0.087 (680/960 done)
# Validation accuracy:  0.087 (681/960 done)
# Validation accuracy:  0.087 (682/960 done)
# Validation accuracy:  0.087 (683/960 done)
# Validation accuracy:  0.087 (684/960 done)
# Validation accuracy:  0.087 (685/960 done)
# Validation accuracy:  0.087 (686/960 done)
# Validation accuracy:  0.087 (687/960 done)
# Validation accuracy:  0.087 (688/960 done)
# Validation accuracy:  0.087 (689/960 done)
# Validation accuracy:  0.087 (690/960 done)
# Validation accuracy:  0.087 (691/960 done)
# Validation accuracy:  0.087 (692/960 done)
# Validation accuracy:  0.087 (693/960 done)
# Validation accuracy:  0.087 (694/960 done)
# Validation accuracy:  0.087 (695/960 done)
# Validation accuracy:  0.087 (696/960 done)
# Validation accuracy:  0.087 (697/960 done)
# Validation accuracy:  0.087 (698/960 done)
# Validation accuracy:  0.087 (699/960 done)
# Validation accuracy:  0.087 (700/960 done)
# Validation accuracy:  0.087 (701/960 done)
# Validation accuracy:  0.087 (702/960 done)
# Validation accuracy:  0.087 (703/960 done)
# Validation accuracy:  0.087 (704/960 done)
# Validation accuracy:  0.087 (705/960 done)
# Validation accuracy:  0.087 (706/960 done)
# Validation accuracy:  0.087 (707/960 done)
# Validation accuracy:  0.087 (708/960 done)
# Validation accuracy:  0.087 (709/960 done)
# Validation accuracy:  0.087 (710/960 done)
# Validation accuracy:  0.087 (711/960 done)
# Validation accuracy:  0.087 (712/960 done)
# Validation accuracy:  0.087 (713/960 done)
# Validation accuracy:  0.087 (714/960 done)
# Validation accuracy:  0.087 (715/960 done)
# Validation accuracy:  0.087 (716/960 done)
# Validation accuracy:  0.087 (717/960 done)
# Validation accuracy:  0.087 (718/960 done)
# Validation accuracy:  0.087 (719/960 done)
# Validation accuracy:  0.087 (720/960 done)
# Validation accuracy:  0.087 (721/960 done)
# Validation accuracy:  0.087 (722/960 done)
# Validation accuracy:  0.087 (723/960 done)
# Validation accuracy:  0.087 (724/960 done)
# Validation accuracy:  0.087 (725/960 done)
# Validation accuracy:  0.087 (726/960 done)
# Validation accuracy:  0.087 (727/960 done)
# Validation accuracy:  0.087 (728/960 done)
# Validation accuracy:  0.087 (729/960 done)
# Validation accuracy:  0.087 (730/960 done)
# Validation accuracy:  0.087 (731/960 done)
# Validation accuracy:  0.087 (732/960 done)
# Validation accuracy:  0.087 (733/960 done)
# Validation accuracy:  0.087 (734/960 done)
# Validation accuracy:  0.087 (735/960 done)
# Validation accuracy:  0.087 (736/960 done)
# Validation accuracy:  0.087 (737/960 done)
# Validation accuracy:  0.087 (738/960 done)
# Validation accuracy:  0.087 (739/960 done)
# Validation accuracy:  0.087 (740/960 done)
# Validation accuracy:  0.087 (741/960 done)
# Validation accuracy:  0.087 (742/960 done)
# Validation accuracy:  0.087 (743/960 done)
# Validation accuracy:  0.087 (744/960 done)
# Validation accuracy:  0.087 (745/960 done)
# Validation accuracy:  0.087 (746/960 done)
# Validation accuracy:  0.087 (747/960 done)
# Validation accuracy:  0.087 (748/960 done)
# Validation accuracy:  0.087 (749/960 done)
# Validation accuracy:  0.087 (750/960 done)
# Validation accuracy:  0.087 (751/960 done)
# Validation accuracy:  0.087 (752/960 done)
# Validation accuracy:  0.087 (753/960 done)
# Validation accuracy:  0.087 (754/960 done)
# Validation accuracy:  0.087 (755/960 done)
# Validation accuracy:  0.087 (756/960 done)
# Validation accuracy:  0.087 (757/960 done)
# Validation accuracy:  0.087 (758/960 done)
# Validation accuracy:  0.087 (759/960 done)
# Validation accuracy:  0.087 (760/960 done)
# Validation accuracy:  0.087 (761/960 done)
# Validation accuracy:  0.087 (762/960 done)
# Validation accuracy:  0.087 (763/960 done)
# Validation accuracy:  0.087 (764/960 done)
# Validation accuracy:  0.087 (765/960 done)
# Validation accuracy:  0.087 (766/960 done)
# Validation accuracy:  0.087 (767/960 done)
# Validation accuracy:  0.087 (768/960 done)
# Validation accuracy:  0.087 (769/960 done)
# Validation accuracy:  0.087 (770/960 done)
# Validation accuracy:  0.087 (771/960 done)
# Validation accuracy:  0.087 (772/960 done)
# Validation accuracy:  0.087 (773/960 done)
# Validation accuracy:  0.087 (774/960 done)
# Validation accuracy:  0.087 (775/960 done)
# Validation accuracy:  0.087 (776/960 done)
# Validation accuracy:  0.087 (777/960 done)
# Validation accuracy:  0.087 (778/960 done)
# Validation accuracy:  0.087 (779/960 done)
# Validation accuracy:  0.087 (780/960 done)
# Validation accuracy:  0.087 (781/960 done)
# Validation accuracy:  0.087 (782/960 done)
# Validation accuracy:  0.087 (783/960 done)
# Validation accuracy:  0.087 (784/960 done)
# Validation accuracy:  0.087 (785/960 done)
# Validation accuracy:  0.087 (786/960 done)
# Validation accuracy:  0.087 (787/960 done)
# Validation accuracy:  0.087 (788/960 done)
# Validation accuracy:  0.087 (789/960 done)
# Validation accuracy:  0.087 (790/960 done)
# Validation accuracy:  0.087 (791/960 done)
# Validation accuracy:  0.087 (792/960 done)
# Validation accuracy:  0.087 (793/960 done)
# Validation accuracy:  0.087 (794/960 done)
# Validation accuracy:  0.087 (795/960 done)
# Validation accuracy:  0.087 (796/960 done)
# Validation accuracy:  0.087 (797/960 done)
# Validation accuracy:  0.087 (798/960 done)
# Validation accuracy:  0.087 (799/960 done)
# Validation accuracy:  0.087 (800/960 done)
# Validation accuracy:  0.087 (801/960 done)
# Validation accuracy:  0.087 (802/960 done)
# Validation accuracy:  0.087 (803/960 done)
# Validation accuracy:  0.087 (804/960 done)
# Validation accuracy:  0.087 (805/960 done)
# Validation accuracy:  0.087 (806/960 done)
# Validation accuracy:  0.087 (807/960 done)
# Validation accuracy:  0.087 (808/960 done)
# Validation accuracy:  0.087 (809/960 done)
# Validation accuracy:  0.087 (810/960 done)
# Validation accuracy:  0.087 (811/960 done)
# Validation accuracy:  0.087 (812/960 done)
# Validation accuracy:  0.087 (813/960 done)
# Validation accuracy:  0.087 (814/960 done)
# Validation accuracy:  0.087 (815/960 done)
# Validation accuracy:  0.087 (816/960 done)
# Validation accuracy:  0.087 (817/960 done)
# Validation accuracy:  0.087 (818/960 done)
# Validation accuracy:  0.087 (819/960 done)
# Validation accuracy:  0.087 (820/960 done)
# Validation accuracy:  0.087 (821/960 done)
# Validation accuracy:  0.087 (822/960 done)
# Validation accuracy:  0.087 (823/960 done)
# Validation accuracy:  0.087 (824/960 done)
# Validation accuracy:  0.087 (825/960 done)
# Validation accuracy:  0.087 (826/960 done)
# Validation accuracy:  0.087 (827/960 done)
# Validation accuracy:  0.087 (828/960 done)
# Validation accuracy:  0.087 (829/960 done)
# Validation accuracy:  0.087 (830/960 done)
# Validation accuracy:  0.087 (831/960 done)
# Validation accuracy:  0.087 (832/960 done)
# Validation accuracy:  0.087 (833/960 done)
# Validation accuracy:  0.087 (834/960 done)
# Validation accuracy:  0.087 (835/960 done)
# Validation accuracy:  0.087 (836/960 done)
# Validation accuracy:  0.087 (837/960 done)
# Validation accuracy:  0.087 (838/960 done)
# Validation accuracy:  0.087 (839/960 done)
# Validation accuracy:  0.087 (840/960 done)
# Validation accuracy:  0.087 (841/960 done)
# Validation accuracy:  0.087 (842/960 done)
# Validation accuracy:  0.087 (843/960 done)
# Validation accuracy:  0.087 (844/960 done)
# Validation accuracy:  0.087 (845/960 done)
# Validation accuracy:  0.087 (846/960 done)
# Validation accuracy:  0.087 (847/960 done)
# Validation accuracy:  0.087 (848/960 done)
# Validation accuracy:  0.087 (849/960 done)
# Validation accuracy:  0.087 (850/960 done)
# Validation accuracy:  0.087 (851/960 done)
# Validation accuracy:  0.087 (852/960 done)
# Validation accuracy:  0.087 (853/960 done)
# Validation accuracy:  0.087 (854/960 done)
# Validation accuracy:  0.087 (855/960 done)
# Validation accuracy:  0.087 (856/960 done)
# Validation accuracy:  0.087 (857/960 done)
# Validation accuracy:  0.087 (858/960 done)
# Validation accuracy:  0.087 (859/960 done)
# Validation accuracy:  0.087 (860/960 done)
# Validation accuracy:  0.087 (861/960 done)
# Validation accuracy:  0.087 (862/960 done)
# Validation accuracy:  0.087 (863/960 done)
# Validation accuracy:  0.087 (864/960 done)
# Validation accuracy:  0.087 (865/960 done)
# Validation accuracy:  0.087 (866/960 done)
# Validation accuracy:  0.087 (867/960 done)
# Validation accuracy:  0.087 (868/960 done)
# Validation accuracy:  0.087 (869/960 done)
# Validation accuracy:  0.087 (870/960 done)
# Validation accuracy:  0.087 (871/960 done)
# Validation accuracy:  0.087 (872/960 done)
# Validation accuracy:  0.087 (873/960 done)
# Validation accuracy:  0.087 (874/960 done)
# Validation accuracy:  0.087 (875/960 done)
# Validation accuracy:  0.087 (876/960 done)
# Validation accuracy:  0.087 (877/960 done)
# Validation accuracy:  0.087 (878/960 done)
# Validation accuracy:  0.087 (879/960 done)
# Validation accuracy:  0.087 (880/960 done)
# Validation accuracy:  0.087 (881/960 done)
# Validation accuracy:  0.087 (882/960 done)
# Validation accuracy:  0.087 (883/960 done)
# Validation accuracy:  0.087 (884/960 done)
# Validation accuracy:  0.087 (885/960 done)
# Validation accuracy:  0.087 (886/960 done)
# Validation accuracy:  0.087 (887/960 done)
# Validation accuracy:  0.087 (888/960 done)
# Validation accuracy:  0.087 (889/960 done)
# Validation accuracy:  0.087 (890/960 done)
# Validation accuracy:  0.087 (891/960 done)
# Validation accuracy:  0.087 (892/960 done)
# Validation accuracy:  0.087 (893/960 done)
# Validation accuracy:  0.087 (894/960 done)
# Validation accuracy:  0.087 (895/960 done)
# Validation accuracy:  0.087 (896/960 done)
# Validation accuracy:  0.087 (897/960 done)
# Validation accuracy:  0.087 (898/960 done)
# Validation accuracy:  0.087 (899/960 done)
# Validation accuracy:  0.087 (900/960 done)
# Validation accuracy:  0.087 (901/960 done)
# Validation accuracy:  0.087 (902/960 done)
# Validation accuracy:  0.087 (903/960 done)
# Validation accuracy:  0.087 (904/960 done)
# Validation accuracy:  0.087 (905/960 done)
# Validation accuracy:  0.087 (906/960 done)
# Validation accuracy:  0.087 (907/960 done)
# Validation accuracy:  0.087 (908/960 done)
# Validation accuracy:  0.087 (909/960 done)
# Validation accuracy:  0.087 (910/960 done)
# Validation accuracy:  0.087 (911/960 done)
# Validation accuracy:  0.087 (912/960 done)
# Validation accuracy:  0.087 (913/960 done)
# Validation accuracy:  0.087 (914/960 done)
# Validation accuracy:  0.087 (915/960 done)
# Validation accuracy:  0.087 (916/960 done)
# Validation accuracy:  0.087 (917/960 done)
# Validation accuracy:  0.087 (918/960 done)
# Validation accuracy:  0.087 (919/960 done)
# Validation accuracy:  0.087 (920/960 done)
# Validation accuracy:  0.087 (921/960 done)
# Validation accuracy:  0.087 (922/960 done)
# Validation accuracy:  0.087 (923/960 done)
# Validation accuracy:  0.087 (924/960 done)
# Validation accuracy:  0.087 (925/960 done)
# Validation accuracy:  0.087 (926/960 done)
# Validation accuracy:  0.087 (927/960 done)
# Validation accuracy:  0.087 (928/960 done)
# Validation accuracy:  0.087 (929/960 done)
# Validation accuracy:  0.087 (930/960 done)
# Validation accuracy:  0.087 (931/960 done)
# Validation accuracy:  0.087 (932/960 done)
# Validation accuracy:  0.087 (933/960 done)
# Validation accuracy:  0.087 (934/960 done)
# Validation accuracy:  0.087 (935/960 done)
# Validation accuracy:  0.087 (936/960 done)
# Validation accuracy:  0.087 (937/960 done)
# Validation accuracy:  0.087 (938/960 done)
# Validation accuracy:  0.087 (939/960 done)
# Validation accuracy:  0.087 (940/960 done)
# Validation accuracy:  0.087 (941/960 done)
# Validation accuracy:  0.087 (942/960 done)
# Validation accuracy:  0.087 (943/960 done)
# Validation accuracy:  0.087 (944/960 done)
# Validation accuracy:  0.087 (945/960 done)
# Validation accuracy:  0.087 (946/960 done)
# Validation accuracy:  0.087 (947/960 done)
# Validation accuracy:  0.087 (948/960 done)
# Validation accuracy:  0.087 (949/960 done)
# Validation accuracy:  0.087 (950/960 done)
# Validation accuracy:  0.087 (951/960 done)
# Validation accuracy:  0.087 (952/960 done)
# Validation accuracy:  0.087 (953/960 done)
# Validation accuracy:  0.087 (954/960 done)
# Validation accuracy:  0.087 (955/960 done)
# Validation accuracy:  0.087 (956/960 done)
# Validation accuracy:  0.087 (957/960 done)
# Validation accuracy:  0.087 (958/960 done)
# Validation accuracy:  0.087 (959/960 done)
# Validation accuracy:  0.087 (960/960 done)

# %%
best_key=-1
best_val=0
for (lr,reg,hs,bs) in results:
    (train_acc,val_acc, stats) = results[(lr,reg,hs,bs)]
    if val_acc > best_val:
        best_val=val_acc
        best_key=(lr,reg,hs,bs)
print(best_key)
# Out:
# (0.001, 0.00025, 60, 200)

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.508
