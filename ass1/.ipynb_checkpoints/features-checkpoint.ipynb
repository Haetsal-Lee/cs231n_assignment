# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by **training a linear classifier on the pixels** of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but **on features that are computed from the raw pixels**.
#
# All of your work for this exercise **will be done in this notebook.**

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a **Histogram of Oriented
# Gradients (HOG)** as well as a **color histogram using the hue channel in HSV**
# color space. We form our final feature vector for each image **by concatenating
# the HOG and color histogram** feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-10, 5e-10, 9e-10, 1e-9, 5e-9, 9e-9, 
                  1e-8, 5e-8, 9e-8, 1e-7, 5e-7, 9e-7, 
                  1e-6, 5e-6, 9e-6, 1e-5, 5e-5, 9e-5, 
                 ]
regularization_strengths = [
                            2.5e0, 7.5e0, 2.5e1, 7.5e1,
                            2.5e2, 7.5e2, 2.5e3, 7.5e3,
                            2.5e4, 7.5e4, 2.5e5, 7.5e5,
                            2.5e6, 7.5e6, 2.5e7, 7.5e7,
                           ]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for (lr, reg)  in [(x,y) for x in learning_rates for y in regularization_strengths]:
    #print('####')
    #print(lr, reg)
    svm = LinearSVM()
    svm.train(X_train_feats, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=False)
    train_accuracy = np.mean(svm.predict((X_train_feats)) == y_train)
    val_accuracy = np.mean(svm.predict(X_val_feats) == y_val)
    results[(lr, reg)] = (train_accuracy, val_accuracy)
    if(val_accuracy > best_val):
        best_val = val_accuracy
        best_svm = svm
    #print(train_accuracy, val_accuracy)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\linear_svm.py:96: RuntimeWarning: overflow encountered in double_scalars
#   loss += reg * np.sum(W * W)
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\linear_svm.py:96: RuntimeWarning: overflow encountered in multiply
#   loss += reg * np.sum(W * W)
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\linear_svm.py:115: RuntimeWarning: overflow encountered in multiply
#   dW += (reg * 2) *W #winbaram
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\linear_svm.py:91: RuntimeWarning: invalid value encountered in less_equal
#   margin[margin<=0] = 0
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\linear_svm.py:109: RuntimeWarning: invalid value encountered in greater
#   margin[margin>0]=1;#winbaram; part of scores[j]
# C:\Users\Winbaram\Desktop\assignment1\cs231n\classifiers\linear_svm.py:85: RuntimeWarning: invalid value encountered in subtract
#   margin = (scores - correct_class_score) + 1
# lr 1.000000e-10 reg 2.500000e+00 train accuracy: 0.085571 val accuracy: 0.081000
# lr 1.000000e-10 reg 7.500000e+00 train accuracy: 0.098816 val accuracy: 0.108000
# lr 1.000000e-10 reg 2.500000e+01 train accuracy: 0.093082 val accuracy: 0.102000
# lr 1.000000e-10 reg 7.500000e+01 train accuracy: 0.101878 val accuracy: 0.091000
# lr 1.000000e-10 reg 2.500000e+02 train accuracy: 0.091796 val accuracy: 0.096000
# lr 1.000000e-10 reg 7.500000e+02 train accuracy: 0.078388 val accuracy: 0.081000
# lr 1.000000e-10 reg 2.500000e+03 train accuracy: 0.090653 val accuracy: 0.083000
# lr 1.000000e-10 reg 7.500000e+03 train accuracy: 0.083102 val accuracy: 0.084000
# lr 1.000000e-10 reg 2.500000e+04 train accuracy: 0.114163 val accuracy: 0.104000
# lr 1.000000e-10 reg 7.500000e+04 train accuracy: 0.082020 val accuracy: 0.087000
# lr 1.000000e-10 reg 2.500000e+05 train accuracy: 0.093000 val accuracy: 0.082000
# lr 1.000000e-10 reg 7.500000e+05 train accuracy: 0.104980 val accuracy: 0.117000
# lr 1.000000e-10 reg 2.500000e+06 train accuracy: 0.089898 val accuracy: 0.084000
# lr 1.000000e-10 reg 7.500000e+06 train accuracy: 0.105531 val accuracy: 0.100000
# lr 1.000000e-10 reg 2.500000e+07 train accuracy: 0.091245 val accuracy: 0.083000
# lr 1.000000e-10 reg 7.500000e+07 train accuracy: 0.414000 val accuracy: 0.410000
# lr 5.000000e-10 reg 2.500000e+00 train accuracy: 0.106776 val accuracy: 0.115000
# lr 5.000000e-10 reg 7.500000e+00 train accuracy: 0.107041 val accuracy: 0.104000
# lr 5.000000e-10 reg 2.500000e+01 train accuracy: 0.099673 val accuracy: 0.094000
# lr 5.000000e-10 reg 7.500000e+01 train accuracy: 0.095061 val accuracy: 0.087000
# lr 5.000000e-10 reg 2.500000e+02 train accuracy: 0.087918 val accuracy: 0.073000
# lr 5.000000e-10 reg 7.500000e+02 train accuracy: 0.105000 val accuracy: 0.115000
# lr 5.000000e-10 reg 2.500000e+03 train accuracy: 0.107020 val accuracy: 0.112000
# lr 5.000000e-10 reg 7.500000e+03 train accuracy: 0.106837 val accuracy: 0.091000
# lr 5.000000e-10 reg 2.500000e+04 train accuracy: 0.114306 val accuracy: 0.132000
# lr 5.000000e-10 reg 7.500000e+04 train accuracy: 0.103694 val accuracy: 0.102000
# lr 5.000000e-10 reg 2.500000e+05 train accuracy: 0.070816 val accuracy: 0.058000
# lr 5.000000e-10 reg 7.500000e+05 train accuracy: 0.085449 val accuracy: 0.087000
# lr 5.000000e-10 reg 2.500000e+06 train accuracy: 0.106490 val accuracy: 0.099000
# lr 5.000000e-10 reg 7.500000e+06 train accuracy: 0.385735 val accuracy: 0.380000
# lr 5.000000e-10 reg 2.500000e+07 train accuracy: 0.415306 val accuracy: 0.418000
# lr 5.000000e-10 reg 7.500000e+07 train accuracy: 0.408061 val accuracy: 0.397000
# lr 9.000000e-10 reg 2.500000e+00 train accuracy: 0.101020 val accuracy: 0.099000
# lr 9.000000e-10 reg 7.500000e+00 train accuracy: 0.099429 val accuracy: 0.115000
# lr 9.000000e-10 reg 2.500000e+01 train accuracy: 0.084878 val accuracy: 0.094000
# lr 9.000000e-10 reg 7.500000e+01 train accuracy: 0.068367 val accuracy: 0.069000
# lr 9.000000e-10 reg 2.500000e+02 train accuracy: 0.116429 val accuracy: 0.112000
# lr 9.000000e-10 reg 7.500000e+02 train accuracy: 0.121755 val accuracy: 0.117000
# lr 9.000000e-10 reg 2.500000e+03 train accuracy: 0.124061 val accuracy: 0.118000
# lr 9.000000e-10 reg 7.500000e+03 train accuracy: 0.096510 val accuracy: 0.102000
# lr 9.000000e-10 reg 2.500000e+04 train accuracy: 0.087286 val accuracy: 0.098000
# lr 9.000000e-10 reg 7.500000e+04 train accuracy: 0.099469 val accuracy: 0.111000
# lr 9.000000e-10 reg 2.500000e+05 train accuracy: 0.085959 val accuracy: 0.087000
# lr 9.000000e-10 reg 7.500000e+05 train accuracy: 0.088776 val accuracy: 0.096000
# lr 9.000000e-10 reg 2.500000e+06 train accuracy: 0.120959 val accuracy: 0.112000
# lr 9.000000e-10 reg 7.500000e+06 train accuracy: 0.415102 val accuracy: 0.417000
# lr 9.000000e-10 reg 2.500000e+07 train accuracy: 0.415816 val accuracy: 0.424000
# lr 9.000000e-10 reg 7.500000e+07 train accuracy: 0.409000 val accuracy: 0.400000
# lr 1.000000e-09 reg 2.500000e+00 train accuracy: 0.103184 val accuracy: 0.122000
# lr 1.000000e-09 reg 7.500000e+00 train accuracy: 0.106061 val accuracy: 0.107000
# lr 1.000000e-09 reg 2.500000e+01 train accuracy: 0.089755 val accuracy: 0.100000
# lr 1.000000e-09 reg 7.500000e+01 train accuracy: 0.091327 val accuracy: 0.086000
# lr 1.000000e-09 reg 2.500000e+02 train accuracy: 0.124939 val accuracy: 0.130000
# lr 1.000000e-09 reg 7.500000e+02 train accuracy: 0.105245 val accuracy: 0.101000
# lr 1.000000e-09 reg 2.500000e+03 train accuracy: 0.094673 val accuracy: 0.085000
# lr 1.000000e-09 reg 7.500000e+03 train accuracy: 0.099551 val accuracy: 0.085000
# lr 1.000000e-09 reg 2.500000e+04 train accuracy: 0.101633 val accuracy: 0.095000
# lr 1.000000e-09 reg 7.500000e+04 train accuracy: 0.091673 val accuracy: 0.089000
# lr 1.000000e-09 reg 2.500000e+05 train accuracy: 0.070367 val accuracy: 0.074000
# lr 1.000000e-09 reg 7.500000e+05 train accuracy: 0.099061 val accuracy: 0.111000
# lr 1.000000e-09 reg 2.500000e+06 train accuracy: 0.121755 val accuracy: 0.108000
# lr 1.000000e-09 reg 7.500000e+06 train accuracy: 0.412510 val accuracy: 0.417000
# lr 1.000000e-09 reg 2.500000e+07 train accuracy: 0.412306 val accuracy: 0.415000
# lr 1.000000e-09 reg 7.500000e+07 train accuracy: 0.404408 val accuracy: 0.421000
# lr 5.000000e-09 reg 2.500000e+00 train accuracy: 0.103612 val accuracy: 0.117000
# lr 5.000000e-09 reg 7.500000e+00 train accuracy: 0.112612 val accuracy: 0.118000
# lr 5.000000e-09 reg 2.500000e+01 train accuracy: 0.083082 val accuracy: 0.074000
# lr 5.000000e-09 reg 7.500000e+01 train accuracy: 0.122082 val accuracy: 0.155000
# lr 5.000000e-09 reg 2.500000e+02 train accuracy: 0.111898 val accuracy: 0.129000
# lr 5.000000e-09 reg 7.500000e+02 train accuracy: 0.113776 val accuracy: 0.107000
# lr 5.000000e-09 reg 2.500000e+03 train accuracy: 0.080408 val accuracy: 0.071000
# lr 5.000000e-09 reg 7.500000e+03 train accuracy: 0.102694 val accuracy: 0.102000
# lr 5.000000e-09 reg 2.500000e+04 train accuracy: 0.104592 val accuracy: 0.111000
# lr 5.000000e-09 reg 7.500000e+04 train accuracy: 0.110388 val accuracy: 0.124000
# lr 5.000000e-09 reg 2.500000e+05 train accuracy: 0.093265 val accuracy: 0.099000
# lr 5.000000e-09 reg 7.500000e+05 train accuracy: 0.415327 val accuracy: 0.419000
# lr 5.000000e-09 reg 2.500000e+06 train accuracy: 0.410388 val accuracy: 0.403000
# lr 5.000000e-09 reg 7.500000e+06 train accuracy: 0.407367 val accuracy: 0.398000
# lr 5.000000e-09 reg 2.500000e+07 train accuracy: 0.400592 val accuracy: 0.393000
# lr 5.000000e-09 reg 7.500000e+07 train accuracy: 0.340980 val accuracy: 0.341000
# lr 9.000000e-09 reg 2.500000e+00 train accuracy: 0.090776 val accuracy: 0.077000
# lr 9.000000e-09 reg 7.500000e+00 train accuracy: 0.096020 val accuracy: 0.092000
# lr 9.000000e-09 reg 2.500000e+01 train accuracy: 0.106020 val accuracy: 0.101000
# lr 9.000000e-09 reg 7.500000e+01 train accuracy: 0.116571 val accuracy: 0.121000
# lr 9.000000e-09 reg 2.500000e+02 train accuracy: 0.090490 val accuracy: 0.095000
# lr 9.000000e-09 reg 7.500000e+02 train accuracy: 0.087245 val accuracy: 0.087000
# lr 9.000000e-09 reg 2.500000e+03 train accuracy: 0.124612 val accuracy: 0.128000
# lr 9.000000e-09 reg 7.500000e+03 train accuracy: 0.100714 val accuracy: 0.084000
# lr 9.000000e-09 reg 2.500000e+04 train accuracy: 0.115122 val accuracy: 0.115000
# lr 9.000000e-09 reg 7.500000e+04 train accuracy: 0.088020 val accuracy: 0.089000
# lr 9.000000e-09 reg 2.500000e+05 train accuracy: 0.235653 val accuracy: 0.252000
# lr 9.000000e-09 reg 7.500000e+05 train accuracy: 0.412286 val accuracy: 0.412000
# lr 9.000000e-09 reg 2.500000e+06 train accuracy: 0.409612 val accuracy: 0.412000
# lr 9.000000e-09 reg 7.500000e+06 train accuracy: 0.406673 val accuracy: 0.413000
# lr 9.000000e-09 reg 2.500000e+07 train accuracy: 0.358347 val accuracy: 0.351000
# lr 9.000000e-09 reg 7.500000e+07 train accuracy: 0.291776 val accuracy: 0.307000
# lr 1.000000e-08 reg 2.500000e+00 train accuracy: 0.100000 val accuracy: 0.106000
# lr 1.000000e-08 reg 7.500000e+00 train accuracy: 0.095898 val accuracy: 0.105000
# lr 1.000000e-08 reg 2.500000e+01 train accuracy: 0.107449 val accuracy: 0.108000
# lr 1.000000e-08 reg 7.500000e+01 train accuracy: 0.099837 val accuracy: 0.120000
# lr 1.000000e-08 reg 2.500000e+02 train accuracy: 0.120571 val accuracy: 0.142000
# lr 1.000000e-08 reg 7.500000e+02 train accuracy: 0.109490 val accuracy: 0.112000
# lr 1.000000e-08 reg 2.500000e+03 train accuracy: 0.109510 val accuracy: 0.090000
# lr 1.000000e-08 reg 7.500000e+03 train accuracy: 0.097469 val accuracy: 0.077000
# lr 1.000000e-08 reg 2.500000e+04 train accuracy: 0.101449 val accuracy: 0.092000
# lr 1.000000e-08 reg 7.500000e+04 train accuracy: 0.102735 val accuracy: 0.113000
# lr 1.000000e-08 reg 2.500000e+05 train accuracy: 0.348245 val accuracy: 0.362000
# lr 1.000000e-08 reg 7.500000e+05 train accuracy: 0.412204 val accuracy: 0.417000
# lr 1.000000e-08 reg 2.500000e+06 train accuracy: 0.407653 val accuracy: 0.412000
# lr 1.000000e-08 reg 7.500000e+06 train accuracy: 0.408327 val accuracy: 0.413000
# lr 1.000000e-08 reg 2.500000e+07 train accuracy: 0.357551 val accuracy: 0.356000
# lr 1.000000e-08 reg 7.500000e+07 train accuracy: 0.242857 val accuracy: 0.239000
# lr 5.000000e-08 reg 2.500000e+00 train accuracy: 0.095327 val accuracy: 0.108000
# lr 5.000000e-08 reg 7.500000e+00 train accuracy: 0.120592 val accuracy: 0.116000
# lr 5.000000e-08 reg 2.500000e+01 train accuracy: 0.103918 val accuracy: 0.101000
# lr 5.000000e-08 reg 7.500000e+01 train accuracy: 0.104082 val accuracy: 0.105000
# lr 5.000000e-08 reg 2.500000e+02 train accuracy: 0.085306 val accuracy: 0.086000
# lr 5.000000e-08 reg 7.500000e+02 train accuracy: 0.108510 val accuracy: 0.115000
# lr 5.000000e-08 reg 2.500000e+03 train accuracy: 0.126980 val accuracy: 0.126000
# lr 5.000000e-08 reg 7.500000e+03 train accuracy: 0.112755 val accuracy: 0.106000
# lr 5.000000e-08 reg 2.500000e+04 train accuracy: 0.191510 val accuracy: 0.198000
# lr 5.000000e-08 reg 7.500000e+04 train accuracy: 0.414918 val accuracy: 0.413000
# lr 5.000000e-08 reg 2.500000e+05 train accuracy: 0.417286 val accuracy: 0.417000
# lr 5.000000e-08 reg 7.500000e+05 train accuracy: 0.404286 val accuracy: 0.391000
# lr 5.000000e-08 reg 2.500000e+06 train accuracy: 0.380020 val accuracy: 0.383000
# lr 5.000000e-08 reg 7.500000e+06 train accuracy: 0.336857 val accuracy: 0.356000
# lr 5.000000e-08 reg 2.500000e+07 train accuracy: 0.127673 val accuracy: 0.153000
# lr 5.000000e-08 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-08 reg 2.500000e+00 train accuracy: 0.101245 val accuracy: 0.109000
# lr 9.000000e-08 reg 7.500000e+00 train accuracy: 0.118612 val accuracy: 0.124000
# lr 9.000000e-08 reg 2.500000e+01 train accuracy: 0.131184 val accuracy: 0.127000
# lr 9.000000e-08 reg 7.500000e+01 train accuracy: 0.138163 val accuracy: 0.160000
# lr 9.000000e-08 reg 2.500000e+02 train accuracy: 0.093551 val accuracy: 0.097000
# lr 9.000000e-08 reg 7.500000e+02 train accuracy: 0.117122 val accuracy: 0.124000
# lr 9.000000e-08 reg 2.500000e+03 train accuracy: 0.155020 val accuracy: 0.149000
# lr 9.000000e-08 reg 7.500000e+03 train accuracy: 0.150694 val accuracy: 0.113000
# lr 9.000000e-08 reg 2.500000e+04 train accuracy: 0.408245 val accuracy: 0.422000
# lr 9.000000e-08 reg 7.500000e+04 train accuracy: 0.416857 val accuracy: 0.424000
# lr 9.000000e-08 reg 2.500000e+05 train accuracy: 0.409510 val accuracy: 0.409000
# lr 9.000000e-08 reg 7.500000e+05 train accuracy: 0.408939 val accuracy: 0.410000
# lr 9.000000e-08 reg 2.500000e+06 train accuracy: 0.370959 val accuracy: 0.353000
# lr 9.000000e-08 reg 7.500000e+06 train accuracy: 0.318429 val accuracy: 0.317000
# lr 9.000000e-08 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-08 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-07 reg 2.500000e+00 train accuracy: 0.121918 val accuracy: 0.104000
# lr 1.000000e-07 reg 7.500000e+00 train accuracy: 0.135714 val accuracy: 0.139000
# lr 1.000000e-07 reg 2.500000e+01 train accuracy: 0.131327 val accuracy: 0.145000
# lr 1.000000e-07 reg 7.500000e+01 train accuracy: 0.084898 val accuracy: 0.093000
# lr 1.000000e-07 reg 2.500000e+02 train accuracy: 0.126245 val accuracy: 0.125000
# lr 1.000000e-07 reg 7.500000e+02 train accuracy: 0.101265 val accuracy: 0.098000
# lr 1.000000e-07 reg 2.500000e+03 train accuracy: 0.136327 val accuracy: 0.127000
# lr 1.000000e-07 reg 7.500000e+03 train accuracy: 0.146980 val accuracy: 0.164000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.416612 val accuracy: 0.416000
# lr 1.000000e-07 reg 7.500000e+04 train accuracy: 0.413694 val accuracy: 0.425000
# lr 1.000000e-07 reg 2.500000e+05 train accuracy: 0.414347 val accuracy: 0.415000
# lr 1.000000e-07 reg 7.500000e+05 train accuracy: 0.400673 val accuracy: 0.398000
# lr 1.000000e-07 reg 2.500000e+06 train accuracy: 0.361449 val accuracy: 0.387000
# lr 1.000000e-07 reg 7.500000e+06 train accuracy: 0.260878 val accuracy: 0.255000
# lr 1.000000e-07 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-07 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-07 reg 2.500000e+00 train accuracy: 0.183388 val accuracy: 0.167000
# lr 5.000000e-07 reg 7.500000e+00 train accuracy: 0.174980 val accuracy: 0.188000
# lr 5.000000e-07 reg 2.500000e+01 train accuracy: 0.188327 val accuracy: 0.193000
# lr 5.000000e-07 reg 7.500000e+01 train accuracy: 0.180265 val accuracy: 0.176000
# lr 5.000000e-07 reg 2.500000e+02 train accuracy: 0.200980 val accuracy: 0.191000
# lr 5.000000e-07 reg 7.500000e+02 train accuracy: 0.232857 val accuracy: 0.239000
# lr 5.000000e-07 reg 2.500000e+03 train accuracy: 0.405755 val accuracy: 0.413000
# lr 5.000000e-07 reg 7.500000e+03 train accuracy: 0.416816 val accuracy: 0.422000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.418020 val accuracy: 0.423000
# lr 5.000000e-07 reg 7.500000e+04 train accuracy: 0.400837 val accuracy: 0.400000
# lr 5.000000e-07 reg 2.500000e+05 train accuracy: 0.390837 val accuracy: 0.406000
# lr 5.000000e-07 reg 7.500000e+05 train accuracy: 0.340898 val accuracy: 0.331000
# lr 5.000000e-07 reg 2.500000e+06 train accuracy: 0.119020 val accuracy: 0.115000
# lr 5.000000e-07 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-07 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-07 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-07 reg 2.500000e+00 train accuracy: 0.248592 val accuracy: 0.276000
# lr 9.000000e-07 reg 7.500000e+00 train accuracy: 0.240041 val accuracy: 0.211000
# lr 9.000000e-07 reg 2.500000e+01 train accuracy: 0.245490 val accuracy: 0.255000
# lr 9.000000e-07 reg 7.500000e+01 train accuracy: 0.253367 val accuracy: 0.261000
# lr 9.000000e-07 reg 2.500000e+02 train accuracy: 0.292612 val accuracy: 0.300000
# lr 9.000000e-07 reg 7.500000e+02 train accuracy: 0.362551 val accuracy: 0.366000
# lr 9.000000e-07 reg 2.500000e+03 train accuracy: 0.413816 val accuracy: 0.406000
# lr 9.000000e-07 reg 7.500000e+03 train accuracy: 0.414347 val accuracy: 0.423000
# lr 9.000000e-07 reg 2.500000e+04 train accuracy: 0.414306 val accuracy: 0.424000
# lr 9.000000e-07 reg 7.500000e+04 train accuracy: 0.404878 val accuracy: 0.402000
# lr 9.000000e-07 reg 2.500000e+05 train accuracy: 0.353612 val accuracy: 0.346000
# lr 9.000000e-07 reg 7.500000e+05 train accuracy: 0.281163 val accuracy: 0.266000
# lr 9.000000e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-07 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-07 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-07 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 2.500000e+00 train accuracy: 0.241714 val accuracy: 0.227000
# lr 1.000000e-06 reg 7.500000e+00 train accuracy: 0.268673 val accuracy: 0.274000
# lr 1.000000e-06 reg 2.500000e+01 train accuracy: 0.243673 val accuracy: 0.271000
# lr 1.000000e-06 reg 7.500000e+01 train accuracy: 0.284490 val accuracy: 0.269000
# lr 1.000000e-06 reg 2.500000e+02 train accuracy: 0.300122 val accuracy: 0.280000
# lr 1.000000e-06 reg 7.500000e+02 train accuracy: 0.376265 val accuracy: 0.386000
# lr 1.000000e-06 reg 2.500000e+03 train accuracy: 0.413878 val accuracy: 0.419000
# lr 1.000000e-06 reg 7.500000e+03 train accuracy: 0.416102 val accuracy: 0.417000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.409143 val accuracy: 0.409000
# lr 1.000000e-06 reg 7.500000e+04 train accuracy: 0.395714 val accuracy: 0.387000
# lr 1.000000e-06 reg 2.500000e+05 train accuracy: 0.370510 val accuracy: 0.365000
# lr 1.000000e-06 reg 7.500000e+05 train accuracy: 0.307796 val accuracy: 0.316000
# lr 1.000000e-06 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 2.500000e+00 train accuracy: 0.398755 val accuracy: 0.400000
# lr 5.000000e-06 reg 7.500000e+00 train accuracy: 0.386918 val accuracy: 0.374000
# lr 5.000000e-06 reg 2.500000e+01 train accuracy: 0.405531 val accuracy: 0.407000
# lr 5.000000e-06 reg 7.500000e+01 train accuracy: 0.410347 val accuracy: 0.414000
# lr 5.000000e-06 reg 2.500000e+02 train accuracy: 0.413020 val accuracy: 0.419000
# lr 5.000000e-06 reg 7.500000e+02 train accuracy: 0.411673 val accuracy: 0.412000
# lr 5.000000e-06 reg 2.500000e+03 train accuracy: 0.406939 val accuracy: 0.393000
# lr 5.000000e-06 reg 7.500000e+03 train accuracy: 0.416224 val accuracy: 0.420000
# lr 5.000000e-06 reg 2.500000e+04 train accuracy: 0.401469 val accuracy: 0.387000
# lr 5.000000e-06 reg 7.500000e+04 train accuracy: 0.329143 val accuracy: 0.330000
# lr 5.000000e-06 reg 2.500000e+05 train accuracy: 0.099653 val accuracy: 0.103000
# lr 5.000000e-06 reg 7.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-06 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 2.500000e+00 train accuracy: 0.405939 val accuracy: 0.416000
# lr 9.000000e-06 reg 7.500000e+00 train accuracy: 0.409939 val accuracy: 0.411000
# lr 9.000000e-06 reg 2.500000e+01 train accuracy: 0.412020 val accuracy: 0.408000
# lr 9.000000e-06 reg 7.500000e+01 train accuracy: 0.414714 val accuracy: 0.417000
# lr 9.000000e-06 reg 2.500000e+02 train accuracy: 0.413898 val accuracy: 0.416000
# lr 9.000000e-06 reg 7.500000e+02 train accuracy: 0.409857 val accuracy: 0.400000
# lr 9.000000e-06 reg 2.500000e+03 train accuracy: 0.415980 val accuracy: 0.422000
# lr 9.000000e-06 reg 7.500000e+03 train accuracy: 0.404061 val accuracy: 0.390000
# lr 9.000000e-06 reg 2.500000e+04 train accuracy: 0.377408 val accuracy: 0.393000
# lr 9.000000e-06 reg 7.500000e+04 train accuracy: 0.269286 val accuracy: 0.268000
# lr 9.000000e-06 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 7.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-06 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 2.500000e+00 train accuracy: 0.411102 val accuracy: 0.426000
# lr 1.000000e-05 reg 7.500000e+00 train accuracy: 0.407102 val accuracy: 0.411000
# lr 1.000000e-05 reg 2.500000e+01 train accuracy: 0.413245 val accuracy: 0.428000
# lr 1.000000e-05 reg 7.500000e+01 train accuracy: 0.416959 val accuracy: 0.418000
# lr 1.000000e-05 reg 2.500000e+02 train accuracy: 0.413102 val accuracy: 0.411000
# lr 1.000000e-05 reg 7.500000e+02 train accuracy: 0.412878 val accuracy: 0.416000
# lr 1.000000e-05 reg 2.500000e+03 train accuracy: 0.413796 val accuracy: 0.420000
# lr 1.000000e-05 reg 7.500000e+03 train accuracy: 0.402878 val accuracy: 0.410000
# lr 1.000000e-05 reg 2.500000e+04 train accuracy: 0.361000 val accuracy: 0.370000
# lr 1.000000e-05 reg 7.500000e+04 train accuracy: 0.287082 val accuracy: 0.284000
# lr 1.000000e-05 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 7.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.500000e+00 train accuracy: 0.429265 val accuracy: 0.430000
# lr 5.000000e-05 reg 7.500000e+00 train accuracy: 0.424286 val accuracy: 0.429000
# lr 5.000000e-05 reg 2.500000e+01 train accuracy: 0.415367 val accuracy: 0.421000
# lr 5.000000e-05 reg 7.500000e+01 train accuracy: 0.413714 val accuracy: 0.417000
# lr 5.000000e-05 reg 2.500000e+02 train accuracy: 0.410347 val accuracy: 0.406000
# lr 5.000000e-05 reg 7.500000e+02 train accuracy: 0.411061 val accuracy: 0.398000
# lr 5.000000e-05 reg 2.500000e+03 train accuracy: 0.376367 val accuracy: 0.369000
# lr 5.000000e-05 reg 7.500000e+03 train accuracy: 0.354490 val accuracy: 0.337000
# lr 5.000000e-05 reg 2.500000e+04 train accuracy: 0.104837 val accuracy: 0.099000
# lr 5.000000e-05 reg 7.500000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 7.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 2.500000e+00 train accuracy: 0.443755 val accuracy: 0.442000
# lr 9.000000e-05 reg 7.500000e+00 train accuracy: 0.433939 val accuracy: 0.438000
# lr 9.000000e-05 reg 2.500000e+01 train accuracy: 0.414837 val accuracy: 0.415000
# lr 9.000000e-05 reg 7.500000e+01 train accuracy: 0.416265 val accuracy: 0.406000
# lr 9.000000e-05 reg 2.500000e+02 train accuracy: 0.414898 val accuracy: 0.410000
# lr 9.000000e-05 reg 7.500000e+02 train accuracy: 0.411367 val accuracy: 0.403000
# lr 9.000000e-05 reg 2.500000e+03 train accuracy: 0.365184 val accuracy: 0.352000
# lr 9.000000e-05 reg 7.500000e+03 train accuracy: 0.283959 val accuracy: 0.278000
# lr 9.000000e-05 reg 2.500000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 7.500000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 7.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 7.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.000000e-05 reg 7.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.442000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.459

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
# HOG feature and color histogram feature pays attention on (shape or texture) and color ratio of image respectively.
# So I think misclassified ones also make sense. The misclassifed plane ones, for example I think the SVM matched sky blue color of plane images.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For **completeness**, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve **over 55% classification accuracy on the test set**; our best model achieves about 60% classification accuracy.

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
num_classes = 10
results = {}
learning_rates = [
                  5e-2, 5.5e-2,
                  6e-2, 6.5e-2,
                 ]
regularization_strengths = [
                            3.0e-4, 4.0e-4,  5.0e-4, 
                           ]
hidden_sizes = [
    300, 400, 500, 600
]
batch_sizes = [
    50, 60, 70,
]
learning_combs = [(lr,reg,hs,bs) for lr in learning_rates for reg in regularization_strengths for hs in hidden_sizes for bs in batch_sizes]
best_net = None
best_val = -1
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
comb_cnt = 0 
for (lr,reg,hs,bs)  in learning_combs:    
    net = TwoLayerNet(input_dim, hs, num_classes)    
    # Train the network
    stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
            num_iters=int(4000), batch_size=bs,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
    # Predict on the validation set
    comb_cnt+=1
    train_accuracy = (net.predict((X_train_feats)) == y_train).mean()
    val_accuracy = (net.predict(X_val_feats) == y_val).mean()
    print('Validation accuracy: ', (lr, reg, hs, bs), val_accuracy, '(%d/%d done)'%(comb_cnt,len(learning_combs)))
    results[(lr, reg, bs)] = (train_accuracy, val_accuracy, stats)
    if(val_accuracy > best_val):
        best_val = val_accuracy
        best_net = net
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# Validation accuracy:  (0.05, 0.0003, 300, 50) 0.524 (1/144 done)
# Validation accuracy:  (0.05, 0.0003, 300, 60) 0.552 (2/144 done)
# Validation accuracy:  (0.05, 0.0003, 300, 70) 0.53 (3/144 done)
# Validation accuracy:  (0.05, 0.0003, 400, 50) 0.524 (4/144 done)
# Validation accuracy:  (0.05, 0.0003, 400, 60) 0.54 (5/144 done)
# Validation accuracy:  (0.05, 0.0003, 400, 70) 0.535 (6/144 done)
# Validation accuracy:  (0.05, 0.0003, 500, 50) 0.536 (7/144 done)
# Validation accuracy:  (0.05, 0.0003, 500, 60) 0.549 (8/144 done)
# Validation accuracy:  (0.05, 0.0003, 500, 70) 0.532 (9/144 done)
# Validation accuracy:  (0.05, 0.0003, 600, 50) 0.54 (10/144 done)
# Validation accuracy:  (0.05, 0.0003, 600, 60) 0.538 (11/144 done)
# Validation accuracy:  (0.05, 0.0003, 600, 70) 0.537 (12/144 done)
# Validation accuracy:  (0.05, 0.0004, 300, 50) 0.544 (13/144 done)
# Validation accuracy:  (0.05, 0.0004, 300, 60) 0.53 (14/144 done)
# Validation accuracy:  (0.05, 0.0004, 300, 70) 0.55 (15/144 done)
# Validation accuracy:  (0.05, 0.0004, 400, 50) 0.533 (16/144 done)
# Validation accuracy:  (0.05, 0.0004, 400, 60) 0.553 (17/144 done)
# Validation accuracy:  (0.05, 0.0004, 400, 70) 0.543 (18/144 done)
# Validation accuracy:  (0.05, 0.0004, 500, 50) 0.531 (19/144 done)
# Validation accuracy:  (0.05, 0.0004, 500, 60) 0.547 (20/144 done)
# Validation accuracy:  (0.05, 0.0004, 500, 70) 0.54 (21/144 done)
# Validation accuracy:  (0.05, 0.0004, 600, 50) 0.54 (22/144 done)
# Validation accuracy:  (0.05, 0.0004, 600, 60) 0.537 (23/144 done)
# Validation accuracy:  (0.05, 0.0004, 600, 70) 0.541 (24/144 done)
# Validation accuracy:  (0.05, 0.0005, 300, 50) 0.54 (25/144 done)
# Validation accuracy:  (0.05, 0.0005, 300, 60) 0.548 (26/144 done)
# Validation accuracy:  (0.05, 0.0005, 300, 70) 0.533 (27/144 done)
# Validation accuracy:  (0.05, 0.0005, 400, 50) 0.544 (28/144 done)
# Validation accuracy:  (0.05, 0.0005, 400, 60) 0.546 (29/144 done)
# Validation accuracy:  (0.05, 0.0005, 400, 70) 0.526 (30/144 done)
# Validation accuracy:  (0.05, 0.0005, 500, 50) 0.537 (31/144 done)
# Validation accuracy:  (0.05, 0.0005, 500, 60) 0.544 (32/144 done)
# Validation accuracy:  (0.05, 0.0005, 500, 70) 0.546 (33/144 done)
# Validation accuracy:  (0.05, 0.0005, 600, 50) 0.537 (34/144 done)
# Validation accuracy:  (0.05, 0.0005, 600, 60) 0.536 (35/144 done)
# Validation accuracy:  (0.05, 0.0005, 600, 70) 0.538 (36/144 done)
# Validation accuracy:  (0.055, 0.0003, 300, 50) 0.548 (37/144 done)
# Validation accuracy:  (0.055, 0.0003, 300, 60) 0.553 (38/144 done)
# Validation accuracy:  (0.055, 0.0003, 300, 70) 0.519 (39/144 done)
# Validation accuracy:  (0.055, 0.0003, 400, 50) 0.537 (40/144 done)
# Validation accuracy:  (0.055, 0.0003, 400, 60) 0.552 (41/144 done)
# Validation accuracy:  (0.055, 0.0003, 400, 70) 0.539 (42/144 done)
# Validation accuracy:  (0.055, 0.0003, 500, 50) 0.528 (43/144 done)
# Validation accuracy:  (0.055, 0.0003, 500, 60) 0.56 (44/144 done)
# Validation accuracy:  (0.055, 0.0003, 500, 70) 0.549 (45/144 done)
# Validation accuracy:  (0.055, 0.0003, 600, 50) 0.537 (46/144 done)
# Validation accuracy:  (0.055, 0.0003, 600, 60) 0.535 (47/144 done)
# Validation accuracy:  (0.055, 0.0003, 600, 70) 0.532 (48/144 done)
# Validation accuracy:  (0.055, 0.0004, 300, 50) 0.528 (49/144 done)
# Validation accuracy:  (0.055, 0.0004, 300, 60) 0.551 (50/144 done)
# Validation accuracy:  (0.055, 0.0004, 300, 70) 0.544 (51/144 done)
# Validation accuracy:  (0.055, 0.0004, 400, 50) 0.559 (52/144 done)
# Validation accuracy:  (0.055, 0.0004, 400, 60) 0.544 (53/144 done)
# Validation accuracy:  (0.055, 0.0004, 400, 70) 0.555 (54/144 done)
# Validation accuracy:  (0.055, 0.0004, 500, 50) 0.53 (55/144 done)
# Validation accuracy:  (0.055, 0.0004, 500, 60) 0.547 (56/144 done)
# Validation accuracy:  (0.055, 0.0004, 500, 70) 0.547 (57/144 done)
# Validation accuracy:  (0.055, 0.0004, 600, 50) 0.536 (58/144 done)
# Validation accuracy:  (0.055, 0.0004, 600, 60) 0.551 (59/144 done)
# Validation accuracy:  (0.055, 0.0004, 600, 70) 0.54 (60/144 done)
# Validation accuracy:  (0.055, 0.0005, 300, 50) 0.534 (61/144 done)
# Validation accuracy:  (0.055, 0.0005, 300, 60) 0.532 (62/144 done)
# Validation accuracy:  (0.055, 0.0005, 300, 70) 0.535 (63/144 done)
# Validation accuracy:  (0.055, 0.0005, 400, 50) 0.534 (64/144 done)
# Validation accuracy:  (0.055, 0.0005, 400, 60) 0.524 (65/144 done)
# Validation accuracy:  (0.055, 0.0005, 400, 70) 0.549 (66/144 done)
# Validation accuracy:  (0.055, 0.0005, 500, 50) 0.538 (67/144 done)
# Validation accuracy:  (0.055, 0.0005, 500, 60) 0.538 (68/144 done)
# Validation accuracy:  (0.055, 0.0005, 500, 70) 0.551 (69/144 done)
# Validation accuracy:  (0.055, 0.0005, 600, 50) 0.54 (70/144 done)
# Validation accuracy:  (0.055, 0.0005, 600, 60) 0.546 (71/144 done)
# Validation accuracy:  (0.055, 0.0005, 600, 70) 0.541 (72/144 done)
# Validation accuracy:  (0.06, 0.0003, 300, 50) 0.539 (73/144 done)
# Validation accuracy:  (0.06, 0.0003, 300, 60) 0.549 (74/144 done)
# Validation accuracy:  (0.06, 0.0003, 300, 70) 0.546 (75/144 done)
# Validation accuracy:  (0.06, 0.0003, 400, 50) 0.556 (76/144 done)
# Validation accuracy:  (0.06, 0.0003, 400, 60) 0.549 (77/144 done)
# Validation accuracy:  (0.06, 0.0003, 400, 70) 0.553 (78/144 done)
# Validation accuracy:  (0.06, 0.0003, 500, 50) 0.555 (79/144 done)
# Validation accuracy:  (0.06, 0.0003, 500, 60) 0.555 (80/144 done)
# Validation accuracy:  (0.06, 0.0003, 500, 70) 0.555 (81/144 done)
# Validation accuracy:  (0.06, 0.0003, 600, 50) 0.552 (82/144 done)
# Validation accuracy:  (0.06, 0.0003, 600, 60) 0.54 (83/144 done)
# Validation accuracy:  (0.06, 0.0003, 600, 70) 0.541 (84/144 done)
# Validation accuracy:  (0.06, 0.0004, 300, 50) 0.537 (85/144 done)
# Validation accuracy:  (0.06, 0.0004, 300, 60) 0.548 (86/144 done)
# Validation accuracy:  (0.06, 0.0004, 300, 70) 0.539 (87/144 done)
# Validation accuracy:  (0.06, 0.0004, 400, 50) 0.539 (88/144 done)
# Validation accuracy:  (0.06, 0.0004, 400, 60) 0.555 (89/144 done)
# Validation accuracy:  (0.06, 0.0004, 400, 70) 0.55 (90/144 done)
# Validation accuracy:  (0.06, 0.0004, 500, 50) 0.546 (91/144 done)
# Validation accuracy:  (0.06, 0.0004, 500, 60) 0.562 (92/144 done)
# Validation accuracy:  (0.06, 0.0004, 500, 70) 0.547 (93/144 done)
# Validation accuracy:  (0.06, 0.0004, 600, 50) 0.543 (94/144 done)
# Validation accuracy:  (0.06, 0.0004, 600, 60) 0.557 (95/144 done)
# Validation accuracy:  (0.06, 0.0004, 600, 70) 0.555 (96/144 done)
# Validation accuracy:  (0.06, 0.0005, 300, 50) 0.543 (97/144 done)
# Validation accuracy:  (0.06, 0.0005, 300, 60) 0.56 (98/144 done)
# Validation accuracy:  (0.06, 0.0005, 300, 70) 0.544 (99/144 done)
# Validation accuracy:  (0.06, 0.0005, 400, 50) 0.547 (100/144 done)
# Validation accuracy:  (0.06, 0.0005, 400, 60) 0.554 (101/144 done)
# Validation accuracy:  (0.06, 0.0005, 400, 70) 0.545 (102/144 done)
# Validation accuracy:  (0.06, 0.0005, 500, 50) 0.555 (103/144 done)
# Validation accuracy:  (0.06, 0.0005, 500, 60) 0.556 (104/144 done)
# Validation accuracy:  (0.06, 0.0005, 500, 70) 0.542 (105/144 done)
# Validation accuracy:  (0.06, 0.0005, 600, 50) 0.554 (106/144 done)
# Validation accuracy:  (0.06, 0.0005, 600, 60) 0.553 (107/144 done)
# Validation accuracy:  (0.06, 0.0005, 600, 70) 0.549 (108/144 done)
# Validation accuracy:  (0.065, 0.0003, 300, 50) 0.541 (109/144 done)
# Validation accuracy:  (0.065, 0.0003, 300, 60) 0.555 (110/144 done)
# Validation accuracy:  (0.065, 0.0003, 300, 70) 0.544 (111/144 done)
# Validation accuracy:  (0.065, 0.0003, 400, 50) 0.541 (112/144 done)
# Validation accuracy:  (0.065, 0.0003, 400, 60) 0.564 (113/144 done)
# Validation accuracy:  (0.065, 0.0003, 400, 70) 0.547 (114/144 done)
# Validation accuracy:  (0.065, 0.0003, 500, 50) 0.558 (115/144 done)
# Validation accuracy:  (0.065, 0.0003, 500, 60) 0.554 (116/144 done)
# Validation accuracy:  (0.065, 0.0003, 500, 70) 0.55 (117/144 done)
# Validation accuracy:  (0.065, 0.0003, 600, 50) 0.556 (118/144 done)
# Validation accuracy:  (0.065, 0.0003, 600, 60) 0.542 (119/144 done)
# Validation accuracy:  (0.065, 0.0003, 600, 70) 0.554 (120/144 done)
# Validation accuracy:  (0.065, 0.0004, 300, 50) 0.562 (121/144 done)
# Validation accuracy:  (0.065, 0.0004, 300, 60) 0.546 (122/144 done)
# Validation accuracy:  (0.065, 0.0004, 300, 70) 0.562 (123/144 done)
# Validation accuracy:  (0.065, 0.0004, 400, 50) 0.547 (124/144 done)
# Validation accuracy:  (0.065, 0.0004, 400, 60) 0.563 (125/144 done)
# Validation accuracy:  (0.065, 0.0004, 400, 70) 0.547 (126/144 done)
# Validation accuracy:  (0.065, 0.0004, 500, 50) 0.524 (127/144 done)
# Validation accuracy:  (0.065, 0.0004, 500, 60) 0.552 (128/144 done)
# Validation accuracy:  (0.065, 0.0004, 500, 70) 0.569 (129/144 done)
# Validation accuracy:  (0.065, 0.0004, 600, 50) 0.554 (130/144 done)
# Validation accuracy:  (0.065, 0.0004, 600, 60) 0.564 (131/144 done)
# Validation accuracy:  (0.065, 0.0004, 600, 70) 0.563 (132/144 done)
# Validation accuracy:  (0.065, 0.0005, 300, 50) 0.534 (133/144 done)
# Validation accuracy:  (0.065, 0.0005, 300, 60) 0.556 (134/144 done)
# Validation accuracy:  (0.065, 0.0005, 300, 70) 0.553 (135/144 done)
# Validation accuracy:  (0.065, 0.0005, 400, 50) 0.544 (136/144 done)
# Validation accuracy:  (0.065, 0.0005, 400, 60) 0.547 (137/144 done)
# Validation accuracy:  (0.065, 0.0005, 400, 70) 0.556 (138/144 done)
# Validation accuracy:  (0.065, 0.0005, 500, 50) 0.565 (139/144 done)
# Validation accuracy:  (0.065, 0.0005, 500, 60) 0.563 (140/144 done)
# Validation accuracy:  (0.065, 0.0005, 500, 70) 0.546 (141/144 done)
# Validation accuracy:  (0.065, 0.0005, 600, 50) 0.54 (142/144 done)
# Validation accuracy:  (0.065, 0.0005, 600, 60) 0.552 (143/144 done)
# Validation accuracy:  (0.065, 0.0005, 600, 70) 0.551 (144/144 done)

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.556

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
